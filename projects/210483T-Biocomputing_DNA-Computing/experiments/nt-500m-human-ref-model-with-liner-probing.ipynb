# %% [markdown]
# # NT-500M Human Ref Model with Liner Probing

# %% [markdown]
# ## 1. Installing Dependancies

# %%
# Install
# !pip install -q biopython transformers datasets huggingface_hub accelerate peft 
# !apt install git-lfs

# %%
from transformers.utils import send_example_telemetry

send_example_telemetry("nucleotide_transformer_dna_sequence_modeling_with_lora_notebook", framework="pytorch")

# %% [markdown]
# ## 2. Loading Model

# %%
# Imports
from transformers import AutoTokenizer, AutoModelForMaskedLM, TrainingArguments, Trainer, AutoModelForSequenceClassification
import torch
from sklearn.metrics import matthews_corrcoef, f1_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
from accelerate.test_utils.testing import get_backend

device, _, _ = get_backend()

# %%
num_labels_promoter = 37
# Load the model
model = AutoModelForSequenceClassification.from_pretrained("InstaDeepAI/nucleotide-transformer-500m-human-ref", num_labels=num_labels_promoter)
model = model.to(device)
# Out:
# Some weights of EsmForSequenceClassification were not initialized from the model checkpoint at InstaDeepAI/nucleotide-transformer-500m-human-ref and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from peft import LoraConfig, TaskType

peft_config = LoraConfig(
    task_type=TaskType.SEQ_CLS, inference_mode=False, r=1, lora_alpha= 32, lora_dropout=0.1, target_modules= ["query", "value"],
    #modules_to_save=["intermediate"] # modules that are not frozen and updated during the training
)

# %%
from peft import get_peft_model

lora_classifier = get_peft_model(model, peft_config) # transform our classifier into a peft model
lora_classifier.print_trainable_parameters()
lora_classifier.to(device) # Put the model on the GPU
# Out:
# trainable params: 1,809,957 || all params: 482,295,595 || trainable%: 0.3753
# PeftModelForSequenceClassification(
#   (base_model): LoraModel(
#     (model): EsmForSequenceClassification(
#       (esm): EsmModel(
#         (embeddings): EsmEmbeddings(
#           (word_embeddings): Embedding(4105, 1280, padding_idx=1)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (position_embeddings): Embedding(1002, 1280, padding_idx=1)
#         )
#         (encoder): EsmEncoder(
#           (layer): ModuleList(
#             (0-23): 24 x EsmLayer(
#               (attention): EsmAttention(
#                 (self): EsmSelfAttention(
#                   (query): lora.Linear(
#                     (base_layer): Linear(in_features=1280, out_features=1280, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1280, out_features=1, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=1, out_features=1280, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (key): Linear(in_features=1280, out_features=1280, bias=True)
#                   (value): lora.Linear(
#                     (base_layer): Linear(in_features=1280, out_features=1280, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1280, out_features=1, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=1, out_features=1280, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): EsmSelfOutput(
#                   (dense): Linear(in_features=1280, out_features=1280, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (LayerNorm): LayerNorm((1280,), eps=1e-12, elementwise_affine=True)
#               )
#               (intermediate): EsmIntermediate(
#                 (dense): Linear(in_features=1280, out_features=5120, bias=True)
#               )
#               (output): EsmOutput(
#                 (dense): Linear(in_features=5120, out_features=1280, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (LayerNorm): LayerNorm((1280,), eps=1e-12, elementwise_affine=True)
#             )
#           )
#           (emb_layer_norm_after): LayerNorm((1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (contact_head): EsmContactPredictionHead(
#           (regression): Linear(in_features=480, out_features=1, bias=True)
#           (activation): Sigmoid()
#         )
#       )
#       (classifier): ModulesToSaveWrapper(
#         (original_module): EsmClassificationHead(
#           (dense): Linear(in_features=1280, out_features=1280, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (out_proj): Linear(in_features=1280, out_features=37, bias=True)
#         )
#         (modules_to_save): ModuleDict(
#           (default): EsmClassificationHead(
#             (dense): Linear(in_features=1280, out_features=1280, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (out_proj): Linear(in_features=1280, out_features=37, bias=True)
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# ## 3.Dataset loading and preparation

# %%
from datasets import load_dataset, Dataset

# Load the promoter dataset from the InstaDeep Hugging Face ressources
train_dataset_promoter = load_dataset(
        "wanglab/kegg",
        "default",
        split="train",
        streaming= False,
    )
test_dataset_promoter = load_dataset(
        "wanglab/kegg",
        "default",
        split="test",
        streaming= False,
    )
val_dataset_promoter = load_dataset(
        "wanglab/kegg",
        "default",
        split="val",
        streaming= False,
    )

# %%
train_sequences_promoter = [
    ref + var for ref, var in zip(train_dataset_promoter['reference_sequence'],
                                  train_dataset_promoter['variant_sequence'])
]
train_labels_promoter = train_dataset_promoter['answer']

# Validation data
validation_sequences_promoter = [
    ref + var for ref, var in zip(val_dataset_promoter['reference_sequence'],
                                  val_dataset_promoter['variant_sequence'])
]
validation_labels_promoter = val_dataset_promoter['answer']

# Test data
test_sequences_promoter = [
    ref + var for ref, var in zip(test_dataset_promoter['reference_sequence'],
                                  test_dataset_promoter['variant_sequence'])
]
test_labels_promoter = test_dataset_promoter['answer']

from sklearn.preprocessing import LabelEncoder

# Collect all labels across splits
all_labels = (
    list(train_labels_promoter) + 
    list(validation_labels_promoter) + 
    list(test_labels_promoter)
)

# Fit the encoder
label_encoder = LabelEncoder()
label_encoder.fit(all_labels)

# Encode each split
train_labels_promoter = label_encoder.transform(train_labels_promoter)
validation_labels_promoter = label_encoder.transform(validation_labels_promoter)
test_labels_promoter = label_encoder.transform(test_labels_promoter)

# Save mappings for later use
label2id = {label: idx for idx, label in enumerate(label_encoder.classes_)}
id2label = {idx: label for label, idx in label2id.items()}

# %% [markdown]
# ## 4.Tokenizing the datasets

# %%
# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("InstaDeepAI/nucleotide-transformer-500m-human-ref")

# %%
# Promoter dataset
ds_train_promoter = Dataset.from_dict({"ref": train_dataset_promoter['reference_sequence'],"var":train_dataset_promoter['variant_sequence'],'labels':train_labels_promoter})
ds_validation_promoter = Dataset.from_dict({"ref":val_dataset_promoter['reference_sequence'],"var":val_dataset_promoter['variant_sequence'],'labels':validation_labels_promoter})
ds_test_promoter = Dataset.from_dict({"ref": test_dataset_promoter['reference_sequence'],"var":test_dataset_promoter['variant_sequence'],'labels':test_labels_promoter})

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)  # move model to GPU once
encoder = model.base_model

def tokenize_function(examples):
    # Tokenize and move to GPU
    ref_tokens = tokenizer(examples["ref"], truncation=True, padding=True, return_tensors="pt").to(device)
    var_tokens = tokenizer(examples["var"], truncation=True, padding=True, return_tensors="pt").to(device)

    with torch.no_grad():
        # ref_out = encoder(**ref_tokens).last_hidden_state.mean(dim=1)
        var_out = encoder(**var_tokens).last_hidden_state.mean(dim=1)
    # Concatenate embeddings
    # outputs = torch.cat([ref_out, var_out], dim=1)  # (batch, 2*hidden)

    # Return as numpy for Hugging Face Dataset
    return {"embeddings": var_out.cpu().numpy()}

# %%
tokenized_datasets_train_promoter = ds_train_promoter.map(
    tokenize_function,
    batched=True,
    batch_size=4,
    remove_columns=["ref","var"],
)
tokenized_datasets_validation_promoter = ds_validation_promoter.map(
    tokenize_function,
    batched=True,
    batch_size=4,
    remove_columns=["ref","var"],
)
tokenized_datasets_test_promoter = ds_test_promoter.map(
    tokenize_function,
    batched=True,
    batch_size=4,
    remove_columns=["ref","var"],
)
# Out:
# Map:   0%|          | 0/1159 [00:00<?, ? examples/s]
# Map:   0%|          | 0/144 [00:00<?, ? examples/s]
# Map:   0%|          | 0/146 [00:00<?, ? examples/s]

# %%
tokenized_datasets_train_promoter.save_to_disk("train_embeddings")
tokenized_datasets_validation_promoter.save_to_disk("val_embeddings")
tokenized_datasets_test_promoter.save_to_disk("test_embeddings")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/1159 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/144 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/146 [00:00<?, ? examples/s]

# %%
len(tokenized_datasets_train_promoter['embeddings'][0])
# Out:
# 1280

# %% [markdown]
# ## 5. Training and evaluation

# %%
import torch.nn as nn

hidden_dim = 1280  # assuming ref_out and var_out are same size

class DualSequenceClassifier(nn.Module):
    def __init__(self, input_dim=hidden_dim, num_classes=37):
        super().__init__()
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        return self.classifier(x)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class EmbeddingDataset(Dataset):
    def __init__(self, embeddings, labels):
        self.embeddings = torch.tensor(embeddings, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.embeddings[idx], self.labels[idx]

train_dataset = EmbeddingDataset(tokenized_datasets_train_promoter["embeddings"], train_labels_promoter)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

val_dataset = EmbeddingDataset(tokenized_datasets_validation_promoter["embeddings"], validation_labels_promoter)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=True)

# %%
import torch
from torch.utils.data import DataLoader
import torch.optim as optim


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_clf = DualSequenceClassifier().to(device)
optimizer = optim.Adam(model_clf.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# Training loop
num_epochs = 1000

for epoch in range(1, num_epochs+1):

    model_clf.train()
    train_loss = 0
    correct_train = 0
    total_train = 0

    for batch_x, batch_y in train_loader:
        batch_x, batch_y = batch_x.to(device), batch_y.to(device)
        optimizer.zero_grad()
        logits = model_clf(batch_x)
        loss = criterion(logits, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * batch_x.size(0)
        _, preds = torch.max(logits, dim=1)
        correct_train += (preds == batch_y).sum().item()
        total_train += batch_x.size(0)

    avg_train_loss = train_loss / total_train
    train_acc = correct_train / total_train

    model_clf.eval()
    val_loss = 0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for val_x, val_y in val_loader:
            val_x, val_y = val_x.to(device), val_y.to(device)
            logits = model_clf(val_x)
            loss = criterion(logits, val_y)

            val_loss += loss.item() * val_x.size(0)
            _, preds = torch.max(logits, dim=1)
            correct_val += (preds == val_y).sum().item()
            total_val += val_x.size(0)

    avg_val_loss = val_loss / total_val
    val_acc = correct_val / total_val

    print(f"Epoch {epoch:02d}: "
          f"Train Loss = {avg_train_loss:.4f}, Train Acc = {train_acc:.4f} | "
          f"Val Loss = {avg_val_loss:.4f}, Val Acc = {val_acc:.4f}")
# Out:
# Epoch 01: Train Loss = 2.7102, Train Acc = 0.2623 | Val Loss = 2.3364, Val Acc = 0.3889
# Epoch 02: Train Loss = 2.1736, Train Acc = 0.4323 | Val Loss = 1.8810, Val Acc = 0.5000
# Epoch 03: Train Loss = 1.7881, Train Acc = 0.5168 | Val Loss = 1.5897, Val Acc = 0.5347
# Epoch 04: Train Loss = 1.5390, Train Acc = 0.5643 | Val Loss = 1.3854, Val Acc = 0.6042
# Epoch 05: Train Loss = 1.3620, Train Acc = 0.6238 | Val Loss = 1.2018, Val Acc = 0.6667
# Epoch 06: Train Loss = 1.1956, Train Acc = 0.6462 | Val Loss = 1.1188, Val Acc = 0.6806
# Epoch 07: Train Loss = 1.0971, Train Acc = 0.6773 | Val Loss = 1.0172, Val Acc = 0.7014
# Epoch 08: Train Loss = 0.9784, Train Acc = 0.7170 | Val Loss = 0.9016, Val Acc = 0.7639
# Epoch 09: Train Loss = 0.9112, Train Acc = 0.7274 | Val Loss = 0.8423, Val Acc = 0.7361
# Epoch 10: Train Loss = 0.8481, Train Acc = 0.7541 | Val Loss = 0.7682, Val Acc = 0.7569
# Epoch 11: Train Loss = 0.7432, Train Acc = 0.7817 | Val Loss = 0.7473, Val Acc = 0.7708
# Epoch 12: Train Loss = 0.7071, Train Acc = 0.7886 | Val Loss = 0.7070, Val Acc = 0.8264
# Epoch 13: Train Loss = 0.6668, Train Acc = 0.8050 | Val Loss = 0.6030, Val Acc = 0.8542
# Epoch 14: Train Loss = 0.6106, Train Acc = 0.8266 | Val Loss = 0.6678, Val Acc = 0.7986
# Epoch 15: Train Loss = 0.5620, Train Acc = 0.8421 | Val Loss = 0.6255, Val Acc = 0.8264
# Epoch 16: Train Loss = 0.5445, Train Acc = 0.8395 | Val Loss = 0.5470, Val Acc = 0.8472
# Epoch 17: Train Loss = 0.4915, Train Acc = 0.8602 | Val Loss = 0.5751, Val Acc = 0.8264
# Epoch 18: Train Loss = 0.4991, Train Acc = 0.8499 | Val Loss = 0.6086, Val Acc = 0.8125
# Epoch 19: Train Loss = 0.4319, Train Acc = 0.8792 | Val Loss = 0.5714, Val Acc = 0.8333
# Epoch 20: Train Loss = 0.4264, Train Acc = 0.8697 | Val Loss = 0.5289, Val Acc = 0.8333
# Epoch 21: Train Loss = 0.4070, Train Acc = 0.8844 | Val Loss = 0.4452, Val Acc = 0.8611
# Epoch 22: Train Loss = 0.3943, Train Acc = 0.8921 | Val Loss = 0.4477, Val Acc = 0.8681
# Epoch 23: Train Loss = 0.3411, Train Acc = 0.9103 | Val Loss = 0.4784, Val Acc = 0.8611
# Epoch 24: Train Loss = 0.3589, Train Acc = 0.8870 | Val Loss = 0.4483, Val Acc = 0.8819
# Epoch 25: Train Loss = 0.3185, Train Acc = 0.8947 | Val Loss = 0.4876, Val Acc = 0.8611
# Epoch 26: Train Loss = 0.3108, Train Acc = 0.9111 | Val Loss = 0.4746, Val Acc = 0.8819
# Epoch 27: Train Loss = 0.2905, Train Acc = 0.9094 | Val Loss = 0.4525, Val Acc = 0.8611
# Epoch 28: Train Loss = 0.2932, Train Acc = 0.9146 | Val Loss = 0.4119, Val Acc = 0.8681
# Epoch 29: Train Loss = 0.2606, Train Acc = 0.9215 | Val Loss = 0.4501, Val Acc = 0.8611
# Epoch 30: Train Loss = 0.2633, Train Acc = 0.9172 | Val Loss = 0.3743, Val Acc = 0.8889
# Epoch 31: Train Loss = 0.2508, Train Acc = 0.9206 | Val Loss = 0.3890, Val Acc = 0.9097
# Epoch 32: Train Loss = 0.2546, Train Acc = 0.9120 | Val Loss = 0.4830, Val Acc = 0.8889
# Epoch 33: Train Loss = 0.2244, Train Acc = 0.9318 | Val Loss = 0.3841, Val Acc = 0.8889
# Epoch 34: Train Loss = 0.2241, Train Acc = 0.9267 | Val Loss = 0.4161, Val Acc = 0.9028
# Epoch 35: Train Loss = 0.1963, Train Acc = 0.9422 | Val Loss = 0.4176, Val Acc = 0.8750
# Epoch 36: Train Loss = 0.2188, Train Acc = 0.9336 | Val Loss = 0.3520, Val Acc = 0.9097
# Epoch 37: Train Loss = 0.1883, Train Acc = 0.9439 | Val Loss = 0.4662, Val Acc = 0.8750
# Epoch 38: Train Loss = 0.1816, Train Acc = 0.9439 | Val Loss = 0.3791, Val Acc = 0.9167
# Epoch 39: Train Loss = 0.1655, Train Acc = 0.9491 | Val Loss = 0.3531, Val Acc = 0.9028
# Epoch 40: Train Loss = 0.1828, Train Acc = 0.9422 | Val Loss = 0.3123, Val Acc = 0.8958
# Epoch 41: Train Loss = 0.1701, Train Acc = 0.9474 | Val Loss = 0.3465, Val Acc = 0.9167
# Epoch 42: Train Loss = 0.1723, Train Acc = 0.9439 | Val Loss = 0.3308, Val Acc = 0.9097
# Epoch 43: Train Loss = 0.1643, Train Acc = 0.9482 | Val Loss = 0.3443, Val Acc = 0.8889
# Epoch 44: Train Loss = 0.1570, Train Acc = 0.9448 | Val Loss = 0.3371, Val Acc = 0.8819
# Epoch 45: Train Loss = 0.1425, Train Acc = 0.9491 | Val Loss = 0.3905, Val Acc = 0.9167
# Epoch 46: Train Loss = 0.1616, Train Acc = 0.9405 | Val Loss = 0.4248, Val Acc = 0.9167
# Epoch 47: Train Loss = 0.1438, Train Acc = 0.9482 | Val Loss = 0.3286, Val Acc = 0.9167
# Epoch 48: Train Loss = 0.1283, Train Acc = 0.9577 | Val Loss = 0.2851, Val Acc = 0.9167
# Epoch 49: Train Loss = 0.1363, Train Acc = 0.9543 | Val Loss = 0.3214, Val Acc = 0.9097
# Epoch 50: Train Loss = 0.1307, Train Acc = 0.9534 | Val Loss = 0.3507, Val Acc = 0.8819
# Epoch 51: Train Loss = 0.1372, Train Acc = 0.9500 | Val Loss = 0.3599, Val Acc = 0.9028
# Epoch 52: Train Loss = 0.1223, Train Acc = 0.9569 | Val Loss = 0.3371, Val Acc = 0.9097
# Epoch 53: Train Loss = 0.1314, Train Acc = 0.9517 | Val Loss = 0.3250, Val Acc = 0.9167
# Epoch 54: Train Loss = 0.1290, Train Acc = 0.9577 | Val Loss = 0.3328, Val Acc = 0.8889
# Epoch 55: Train Loss = 0.1326, Train Acc = 0.9594 | Val Loss = 0.3886, Val Acc = 0.9028
# Epoch 56: Train Loss = 0.1225, Train Acc = 0.9551 | Val Loss = 0.3529, Val Acc = 0.9097
# Epoch 57: Train Loss = 0.1394, Train Acc = 0.9482 | Val Loss = 0.2965, Val Acc = 0.9097
# Epoch 58: Train Loss = 0.1107, Train Acc = 0.9603 | Val Loss = 0.3204, Val Acc = 0.9236
# Epoch 59: Train Loss = 0.1204, Train Acc = 0.9534 | Val Loss = 0.3076, Val Acc = 0.9028
# Epoch 60: Train Loss = 0.1050, Train Acc = 0.9672 | Val Loss = 0.3228, Val Acc = 0.9236
# Epoch 61: Train Loss = 0.1048, Train Acc = 0.9560 | Val Loss = 0.3082, Val Acc = 0.9167
# Epoch 62: Train Loss = 0.1054, Train Acc = 0.9551 | Val Loss = 0.3412, Val Acc = 0.8819
# Epoch 63: Train Loss = 0.0968, Train Acc = 0.9629 | Val Loss = 0.3930, Val Acc = 0.9236
# Epoch 64: Train Loss = 0.1113, Train Acc = 0.9560 | Val Loss = 0.2902, Val Acc = 0.9097
# Epoch 65: Train Loss = 0.1232, Train Acc = 0.9577 | Val Loss = 0.2496, Val Acc = 0.9028
# Epoch 66: Train Loss = 0.1202, Train Acc = 0.9551 | Val Loss = 0.3641, Val Acc = 0.8819
# Epoch 67: Train Loss = 0.1079, Train Acc = 0.9551 | Val Loss = 0.2993, Val Acc = 0.9167
# Epoch 68: Train Loss = 0.0904, Train Acc = 0.9672 | Val Loss = 0.3552, Val Acc = 0.8958
# Epoch 69: Train Loss = 0.0905, Train Acc = 0.9612 | Val Loss = 0.3229, Val Acc = 0.9097
# Epoch 70: Train Loss = 0.0965, Train Acc = 0.9629 | Val Loss = 0.3366, Val Acc = 0.9097
# Epoch 71: Train Loss = 0.1521, Train Acc = 0.9465 | Val Loss = 0.3598, Val Acc = 0.9097
# Epoch 72: Train Loss = 0.1079, Train Acc = 0.9543 | Val Loss = 0.2916, Val Acc = 0.9167
# Epoch 73: Train Loss = 0.1061, Train Acc = 0.9551 | Val Loss = 0.3659, Val Acc = 0.9306
# Epoch 74: Train Loss = 0.0961, Train Acc = 0.9612 | Val Loss = 0.3728, Val Acc = 0.9236
# Epoch 75: Train Loss = 0.0884, Train Acc = 0.9638 | Val Loss = 0.3570, Val Acc = 0.9306
# Epoch 76: Train Loss = 0.0908, Train Acc = 0.9646 | Val Loss = 0.3641, Val Acc = 0.9167
# Epoch 77: Train Loss = 0.0968, Train Acc = 0.9620 | Val Loss = 0.4163, Val Acc = 0.9236
# Epoch 78: Train Loss = 0.0867, Train Acc = 0.9629 | Val Loss = 0.3685, Val Acc = 0.9236
# Epoch 79: Train Loss = 0.0885, Train Acc = 0.9664 | Val Loss = 0.3436, Val Acc = 0.9097
# Epoch 80: Train Loss = 0.0842, Train Acc = 0.9672 | Val Loss = 0.3387, Val Acc = 0.9167
# Epoch 81: Train Loss = 0.0849, Train Acc = 0.9698 | Val Loss = 0.3237, Val Acc = 0.9306
# Epoch 82: Train Loss = 0.0897, Train Acc = 0.9638 | Val Loss = 0.3511, Val Acc = 0.9306
# Epoch 83: Train Loss = 0.0921, Train Acc = 0.9664 | Val Loss = 0.3534, Val Acc = 0.9167
# Epoch 84: Train Loss = 0.1025, Train Acc = 0.9577 | Val Loss = 0.3766, Val Acc = 0.9097
# Epoch 85: Train Loss = 0.0924, Train Acc = 0.9612 | Val Loss = 0.3141, Val Acc = 0.9236
# Epoch 86: Train Loss = 0.1010, Train Acc = 0.9586 | Val Loss = 0.4236, Val Acc = 0.9167
# Epoch 87: Train Loss = 0.1074, Train Acc = 0.9560 | Val Loss = 0.4322, Val Acc = 0.9028
# Epoch 88: Train Loss = 0.1080, Train Acc = 0.9551 | Val Loss = 0.4184, Val Acc = 0.9167
# Epoch 89: Train Loss = 0.1306, Train Acc = 0.9517 | Val Loss = 0.4285, Val Acc = 0.9167
# Epoch 90: Train Loss = 0.0994, Train Acc = 0.9629 | Val Loss = 0.3704, Val Acc = 0.9167
# Epoch 91: Train Loss = 0.0955, Train Acc = 0.9664 | Val Loss = 0.2849, Val Acc = 0.9028
# Epoch 92: Train Loss = 0.0750, Train Acc = 0.9681 | Val Loss = 0.3897, Val Acc = 0.9167
# Epoch 93: Train Loss = 0.0843, Train Acc = 0.9646 | Val Loss = 0.3832, Val Acc = 0.9236
# Epoch 94: Train Loss = 0.0772, Train Acc = 0.9689 | Val Loss = 0.3370, Val Acc = 0.9167
# Epoch 95: Train Loss = 0.0873, Train Acc = 0.9646 | Val Loss = 0.3531, Val Acc = 0.9167
# Epoch 96: Train Loss = 0.0757, Train Acc = 0.9672 | Val Loss = 0.3833, Val Acc = 0.9167
# Epoch 97: Train Loss = 0.0763, Train Acc = 0.9638 | Val Loss = 0.3964, Val Acc = 0.9167
# Epoch 98: Train Loss = 0.0855, Train Acc = 0.9638 | Val Loss = 0.3673, Val Acc = 0.9167
# Epoch 99: Train Loss = 0.1029, Train Acc = 0.9551 | Val Loss = 0.3263, Val Acc = 0.9444
# Epoch 100: Train Loss = 0.1242, Train Acc = 0.9534 | Val Loss = 0.4077, Val Acc = 0.9028
# Epoch 101: Train Loss = 0.0941, Train Acc = 0.9620 | Val Loss = 0.4133, Val Acc = 0.8958
# Epoch 102: Train Loss = 0.0948, Train Acc = 0.9569 | Val Loss = 0.3707, Val Acc = 0.9236
# Epoch 103: Train Loss = 0.0876, Train Acc = 0.9612 | Val Loss = 0.4544, Val Acc = 0.9167
# Epoch 104: Train Loss = 0.0982, Train Acc = 0.9594 | Val Loss = 0.3509, Val Acc = 0.8889
# Epoch 105: Train Loss = 0.0963, Train Acc = 0.9612 | Val Loss = 0.3229, Val Acc = 0.9236
# Epoch 106: Train Loss = 0.0798, Train Acc = 0.9620 | Val Loss = 0.3954, Val Acc = 0.9028
# Epoch 107: Train Loss = 0.0733, Train Acc = 0.9707 | Val Loss = 0.4660, Val Acc = 0.8958
# Epoch 108: Train Loss = 0.0753, Train Acc = 0.9646 | Val Loss = 0.3854, Val Acc = 0.9167
# Epoch 109: Train Loss = 0.0768, Train Acc = 0.9681 | Val Loss = 0.4286, Val Acc = 0.9097
# Epoch 110: Train Loss = 0.0757, Train Acc = 0.9672 | Val Loss = 0.3851, Val Acc = 0.9236
# Epoch 111: Train Loss = 0.0742, Train Acc = 0.9646 | Val Loss = 0.4100, Val Acc = 0.9236
# Epoch 112: Train Loss = 0.0745, Train Acc = 0.9681 | Val Loss = 0.4424, Val Acc = 0.9028
# Epoch 113: Train Loss = 0.0782, Train Acc = 0.9672 | Val Loss = 0.4647, Val Acc = 0.9306
# Epoch 114: Train Loss = 0.0734, Train Acc = 0.9672 | Val Loss = 0.3953, Val Acc = 0.8958
# Epoch 115: Train Loss = 0.0720, Train Acc = 0.9698 | Val Loss = 0.3690, Val Acc = 0.9236
# Epoch 116: Train Loss = 0.0779, Train Acc = 0.9664 | Val Loss = 0.4044, Val Acc = 0.9236
# Epoch 117: Train Loss = 0.0781, Train Acc = 0.9629 | Val Loss = 0.4205, Val Acc = 0.9167
# Epoch 118: Train Loss = 0.0754, Train Acc = 0.9629 | Val Loss = 0.4070, Val Acc = 0.9097
# Epoch 119: Train Loss = 0.1013, Train Acc = 0.9586 | Val Loss = 0.5040, Val Acc = 0.8958
# Epoch 120: Train Loss = 0.0923, Train Acc = 0.9646 | Val Loss = 0.4097, Val Acc = 0.9028
# Epoch 121: Train Loss = 0.0834, Train Acc = 0.9681 | Val Loss = 0.4001, Val Acc = 0.9097
# Epoch 122: Train Loss = 0.0813, Train Acc = 0.9638 | Val Loss = 0.3752, Val Acc = 0.9375
# Epoch 123: Train Loss = 0.0757, Train Acc = 0.9629 | Val Loss = 0.3709, Val Acc = 0.9028
# Epoch 124: Train Loss = 0.0774, Train Acc = 0.9664 | Val Loss = 0.3929, Val Acc = 0.9236
# Epoch 125: Train Loss = 0.0691, Train Acc = 0.9655 | Val Loss = 0.3928, Val Acc = 0.9097
# Epoch 126: Train Loss = 0.0674, Train Acc = 0.9707 | Val Loss = 0.3706, Val Acc = 0.9306
# Epoch 127: Train Loss = 0.0839, Train Acc = 0.9672 | Val Loss = 0.4709, Val Acc = 0.9306
# Epoch 128: Train Loss = 0.0821, Train Acc = 0.9646 | Val Loss = 0.5207, Val Acc = 0.9097
# Epoch 129: Train Loss = 0.0848, Train Acc = 0.9569 | Val Loss = 0.3705, Val Acc = 0.9167
# Epoch 130: Train Loss = 0.0724, Train Acc = 0.9664 | Val Loss = 0.4340, Val Acc = 0.9097
# Epoch 131: Train Loss = 0.0782, Train Acc = 0.9672 | Val Loss = 0.3857, Val Acc = 0.9097
# Epoch 132: Train Loss = 0.0825, Train Acc = 0.9664 | Val Loss = 0.3803, Val Acc = 0.9167
# Epoch 133: Train Loss = 0.0846, Train Acc = 0.9672 | Val Loss = 0.5036, Val Acc = 0.9028
# Epoch 134: Train Loss = 0.0886, Train Acc = 0.9655 | Val Loss = 0.4064, Val Acc = 0.9028
# Epoch 135: Train Loss = 0.1625, Train Acc = 0.9413 | Val Loss = 0.3571, Val Acc = 0.9028
# Epoch 136: Train Loss = 0.1361, Train Acc = 0.9474 | Val Loss = 0.4440, Val Acc = 0.8958
# Epoch 137: Train Loss = 0.1049, Train Acc = 0.9534 | Val Loss = 0.4091, Val Acc = 0.9097
# Epoch 138: Train Loss = 0.0768, Train Acc = 0.9655 | Val Loss = 0.4727, Val Acc = 0.9167
# Epoch 139: Train Loss = 0.0921, Train Acc = 0.9586 | Val Loss = 0.4526, Val Acc = 0.9167
# Epoch 140: Train Loss = 0.0720, Train Acc = 0.9681 | Val Loss = 0.4338, Val Acc = 0.9167
# Epoch 141: Train Loss = 0.0738, Train Acc = 0.9689 | Val Loss = 0.4260, Val Acc = 0.9167
# Epoch 142: Train Loss = 0.0730, Train Acc = 0.9689 | Val Loss = 0.3869, Val Acc = 0.9097
# Epoch 143: Train Loss = 0.0631, Train Acc = 0.9707 | Val Loss = 0.3975, Val Acc = 0.9167
# Epoch 144: Train Loss = 0.0730, Train Acc = 0.9698 | Val Loss = 0.3957, Val Acc = 0.9167
# Epoch 145: Train Loss = 0.0683, Train Acc = 0.9724 | Val Loss = 0.3821, Val Acc = 0.9097
# Epoch 146: Train Loss = 0.0621, Train Acc = 0.9664 | Val Loss = 0.4481, Val Acc = 0.9028
# Epoch 147: Train Loss = 0.0740, Train Acc = 0.9646 | Val Loss = 0.3780, Val Acc = 0.9097
# Epoch 148: Train Loss = 0.0743, Train Acc = 0.9655 | Val Loss = 0.3621, Val Acc = 0.9236
# Epoch 149: Train Loss = 0.0720, Train Acc = 0.9664 | Val Loss = 0.5214, Val Acc = 0.8958
# Epoch 150: Train Loss = 0.1251, Train Acc = 0.9517 | Val Loss = 0.4498, Val Acc = 0.9167
# Epoch 151: Train Loss = 0.0841, Train Acc = 0.9655 | Val Loss = 0.4289, Val Acc = 0.9097
# Epoch 152: Train Loss = 0.0662, Train Acc = 0.9689 | Val Loss = 0.3974, Val Acc = 0.9236
# Epoch 153: Train Loss = 0.0739, Train Acc = 0.9620 | Val Loss = 0.4157, Val Acc = 0.9097
# Epoch 154: Train Loss = 0.0681, Train Acc = 0.9664 | Val Loss = 0.4835, Val Acc = 0.9028
# Epoch 155: Train Loss = 0.0744, Train Acc = 0.9698 | Val Loss = 0.3988, Val Acc = 0.8958
# Epoch 156: Train Loss = 0.0767, Train Acc = 0.9603 | Val Loss = 0.4469, Val Acc = 0.9097
# Epoch 157: Train Loss = 0.0784, Train Acc = 0.9629 | Val Loss = 0.4826, Val Acc = 0.8958
# Epoch 158: Train Loss = 0.0766, Train Acc = 0.9681 | Val Loss = 0.5602, Val Acc = 0.9028
# Epoch 159: Train Loss = 0.1159, Train Acc = 0.9560 | Val Loss = 0.4719, Val Acc = 0.8958
# Epoch 160: Train Loss = 0.0945, Train Acc = 0.9646 | Val Loss = 0.3580, Val Acc = 0.9097
# Epoch 161: Train Loss = 0.0779, Train Acc = 0.9638 | Val Loss = 0.5460, Val Acc = 0.9028
# Epoch 162: Train Loss = 0.0760, Train Acc = 0.9646 | Val Loss = 0.4098, Val Acc = 0.9167
# Epoch 163: Train Loss = 0.0683, Train Acc = 0.9698 | Val Loss = 0.3696, Val Acc = 0.9097
# Epoch 164: Train Loss = 0.0734, Train Acc = 0.9681 | Val Loss = 0.3605, Val Acc = 0.9097
# Epoch 165: Train Loss = 0.0660, Train Acc = 0.9698 | Val Loss = 0.4406, Val Acc = 0.9097
# Epoch 166: Train Loss = 0.1042, Train Acc = 0.9603 | Val Loss = 0.4495, Val Acc = 0.9097
# Epoch 167: Train Loss = 0.0920, Train Acc = 0.9646 | Val Loss = 0.4429, Val Acc = 0.9167
# Epoch 168: Train Loss = 0.0771, Train Acc = 0.9629 | Val Loss = 0.4788, Val Acc = 0.8889
# Epoch 169: Train Loss = 0.0699, Train Acc = 0.9681 | Val Loss = 0.4235, Val Acc = 0.9236
# Epoch 170: Train Loss = 0.0840, Train Acc = 0.9620 | Val Loss = 0.5335, Val Acc = 0.9028
# Epoch 171: Train Loss = 0.0793, Train Acc = 0.9629 | Val Loss = 0.3858, Val Acc = 0.9028
# Epoch 172: Train Loss = 0.0663, Train Acc = 0.9681 | Val Loss = 0.4073, Val Acc = 0.9028
# Epoch 173: Train Loss = 0.0996, Train Acc = 0.9525 | Val Loss = 0.4888, Val Acc = 0.8958
# Epoch 174: Train Loss = 0.0848, Train Acc = 0.9646 | Val Loss = 0.5031, Val Acc = 0.9028
# Epoch 175: Train Loss = 0.0923, Train Acc = 0.9612 | Val Loss = 0.4776, Val Acc = 0.9167
# Epoch 176: Train Loss = 0.0823, Train Acc = 0.9664 | Val Loss = 0.4478, Val Acc = 0.9236
# Epoch 177: Train Loss = 0.0786, Train Acc = 0.9638 | Val Loss = 0.4468, Val Acc = 0.9028
# Epoch 178: Train Loss = 0.0934, Train Acc = 0.9551 | Val Loss = 0.2730, Val Acc = 0.9167
# Epoch 179: Train Loss = 0.0944, Train Acc = 0.9638 | Val Loss = 0.5126, Val Acc = 0.9167
# Epoch 180: Train Loss = 0.0775, Train Acc = 0.9629 | Val Loss = 0.4356, Val Acc = 0.9097
# Epoch 181: Train Loss = 0.0775, Train Acc = 0.9638 | Val Loss = 0.4307, Val Acc = 0.8889
# Epoch 182: Train Loss = 0.0686, Train Acc = 0.9681 | Val Loss = 0.4738, Val Acc = 0.9236
# Epoch 183: Train Loss = 0.1129, Train Acc = 0.9594 | Val Loss = 0.5165, Val Acc = 0.8958
# Epoch 184: Train Loss = 0.1076, Train Acc = 0.9594 | Val Loss = 0.3471, Val Acc = 0.9167
# Epoch 185: Train Loss = 0.0769, Train Acc = 0.9629 | Val Loss = 0.3701, Val Acc = 0.9236
# Epoch 186: Train Loss = 0.0740, Train Acc = 0.9646 | Val Loss = 0.5082, Val Acc = 0.9167
# Epoch 187: Train Loss = 0.0712, Train Acc = 0.9638 | Val Loss = 0.4873, Val Acc = 0.9375
# Epoch 188: Train Loss = 0.0703, Train Acc = 0.9655 | Val Loss = 0.4186, Val Acc = 0.9167
# Epoch 189: Train Loss = 0.0632, Train Acc = 0.9664 | Val Loss = 0.4160, Val Acc = 0.9097
# Epoch 190: Train Loss = 0.0661, Train Acc = 0.9672 | Val Loss = 0.4517, Val Acc = 0.9028
# Epoch 191: Train Loss = 0.0598, Train Acc = 0.9741 | Val Loss = 0.4661, Val Acc = 0.9167
# Epoch 192: Train Loss = 0.0673, Train Acc = 0.9646 | Val Loss = 0.4534, Val Acc = 0.9028
# Epoch 193: Train Loss = 0.0600, Train Acc = 0.9707 | Val Loss = 0.4563, Val Acc = 0.9028
# Epoch 194: Train Loss = 0.0649, Train Acc = 0.9689 | Val Loss = 0.4681, Val Acc = 0.9167
# Epoch 195: Train Loss = 0.0656, Train Acc = 0.9672 | Val Loss = 0.3937, Val Acc = 0.9236
# Epoch 196: Train Loss = 0.0630, Train Acc = 0.9689 | Val Loss = 0.3067, Val Acc = 0.9375
# Epoch 197: Train Loss = 0.0684, Train Acc = 0.9681 | Val Loss = 0.4072, Val Acc = 0.9028
# Epoch 198: Train Loss = 0.0694, Train Acc = 0.9672 | Val Loss = 0.4996, Val Acc = 0.9236
# Epoch 199: Train Loss = 0.0677, Train Acc = 0.9672 | Val Loss = 0.4895, Val Acc = 0.9097
# Epoch 200: Train Loss = 0.0911, Train Acc = 0.9612 | Val Loss = 0.4116, Val Acc = 0.9306
# Epoch 201: Train Loss = 0.1025, Train Acc = 0.9534 | Val Loss = 0.4572, Val Acc = 0.9306
# Epoch 202: Train Loss = 0.0851, Train Acc = 0.9586 | Val Loss = 0.3866, Val Acc = 0.9306
# Epoch 203: Train Loss = 0.1206, Train Acc = 0.9508 | Val Loss = 0.4413, Val Acc = 0.9236
# Epoch 204: Train Loss = 0.1127, Train Acc = 0.9569 | Val Loss = 0.4270, Val Acc = 0.9306
# Epoch 205: Train Loss = 0.0773, Train Acc = 0.9646 | Val Loss = 0.5101, Val Acc = 0.9097
# Epoch 206: Train Loss = 0.0695, Train Acc = 0.9698 | Val Loss = 0.4747, Val Acc = 0.9028
# Epoch 207: Train Loss = 0.0745, Train Acc = 0.9629 | Val Loss = 0.5290, Val Acc = 0.9236
# Epoch 208: Train Loss = 0.0680, Train Acc = 0.9664 | Val Loss = 0.4028, Val Acc = 0.9306
# Epoch 209: Train Loss = 0.0684, Train Acc = 0.9689 | Val Loss = 0.4060, Val Acc = 0.9097
# Epoch 210: Train Loss = 0.0732, Train Acc = 0.9672 | Val Loss = 0.4432, Val Acc = 0.9097
# Epoch 211: Train Loss = 0.0933, Train Acc = 0.9629 | Val Loss = 0.3794, Val Acc = 0.9167
# Epoch 212: Train Loss = 0.0736, Train Acc = 0.9681 | Val Loss = 0.3898, Val Acc = 0.9236
# Epoch 213: Train Loss = 0.0632, Train Acc = 0.9629 | Val Loss = 0.4887, Val Acc = 0.9167
# Epoch 214: Train Loss = 0.0584, Train Acc = 0.9733 | Val Loss = 0.4333, Val Acc = 0.9444
# Epoch 215: Train Loss = 0.0618, Train Acc = 0.9698 | Val Loss = 0.4263, Val Acc = 0.9306
# Epoch 216: Train Loss = 0.0634, Train Acc = 0.9689 | Val Loss = 0.4099, Val Acc = 0.9236
# Epoch 217: Train Loss = 0.0661, Train Acc = 0.9664 | Val Loss = 0.4625, Val Acc = 0.9306
# Epoch 218: Train Loss = 0.0633, Train Acc = 0.9707 | Val Loss = 0.4191, Val Acc = 0.9375
# Epoch 219: Train Loss = 0.0626, Train Acc = 0.9672 | Val Loss = 0.5353, Val Acc = 0.9236
# Epoch 220: Train Loss = 0.0716, Train Acc = 0.9664 | Val Loss = 0.4837, Val Acc = 0.9306
# Epoch 221: Train Loss = 0.0592, Train Acc = 0.9715 | Val Loss = 0.5168, Val Acc = 0.9028
# Epoch 222: Train Loss = 0.0728, Train Acc = 0.9664 | Val Loss = 0.4544, Val Acc = 0.9236
# Epoch 223: Train Loss = 0.0686, Train Acc = 0.9672 | Val Loss = 0.5254, Val Acc = 0.9097
# Epoch 224: Train Loss = 0.0911, Train Acc = 0.9525 | Val Loss = 0.4636, Val Acc = 0.9097
# Epoch 225: Train Loss = 0.0929, Train Acc = 0.9646 | Val Loss = 0.4335, Val Acc = 0.9236
# Epoch 226: Train Loss = 0.0917, Train Acc = 0.9577 | Val Loss = 0.5744, Val Acc = 0.8958
# Epoch 227: Train Loss = 0.1049, Train Acc = 0.9560 | Val Loss = 0.6841, Val Acc = 0.8750
# Epoch 228: Train Loss = 0.1027, Train Acc = 0.9594 | Val Loss = 0.5647, Val Acc = 0.9028
# Epoch 229: Train Loss = 0.0752, Train Acc = 0.9646 | Val Loss = 0.4675, Val Acc = 0.9236
# Epoch 230: Train Loss = 0.0657, Train Acc = 0.9664 | Val Loss = 0.5087, Val Acc = 0.8958
# Epoch 231: Train Loss = 0.0724, Train Acc = 0.9629 | Val Loss = 0.4705, Val Acc = 0.9167
# Epoch 232: Train Loss = 0.0633, Train Acc = 0.9733 | Val Loss = 0.5022, Val Acc = 0.9097
# Epoch 233: Train Loss = 0.0613, Train Acc = 0.9741 | Val Loss = 0.4643, Val Acc = 0.9236
# Epoch 234: Train Loss = 0.0676, Train Acc = 0.9664 | Val Loss = 0.4283, Val Acc = 0.9028
# Epoch 235: Train Loss = 0.0786, Train Acc = 0.9620 | Val Loss = 0.5059, Val Acc = 0.8958
# Epoch 236: Train Loss = 0.0690, Train Acc = 0.9672 | Val Loss = 0.5576, Val Acc = 0.9028
# Epoch 237: Train Loss = 0.0792, Train Acc = 0.9664 | Val Loss = 0.5092, Val Acc = 0.9097
# Epoch 238: Train Loss = 0.0621, Train Acc = 0.9733 | Val Loss = 0.4641, Val Acc = 0.9375
# Epoch 239: Train Loss = 0.0721, Train Acc = 0.9689 | Val Loss = 0.5673, Val Acc = 0.9097
# Epoch 240: Train Loss = 0.0625, Train Acc = 0.9707 | Val Loss = 0.4845, Val Acc = 0.9236
# Epoch 241: Train Loss = 0.0646, Train Acc = 0.9750 | Val Loss = 0.5307, Val Acc = 0.9028
# Epoch 242: Train Loss = 0.0637, Train Acc = 0.9672 | Val Loss = 0.4548, Val Acc = 0.9097
# Epoch 243: Train Loss = 0.0588, Train Acc = 0.9715 | Val Loss = 0.4461, Val Acc = 0.9167
# Epoch 244: Train Loss = 0.0610, Train Acc = 0.9698 | Val Loss = 0.4954, Val Acc = 0.9236
# Epoch 245: Train Loss = 0.0653, Train Acc = 0.9646 | Val Loss = 0.5330, Val Acc = 0.9097
# Epoch 246: Train Loss = 0.0641, Train Acc = 0.9715 | Val Loss = 0.4662, Val Acc = 0.9236
# Epoch 247: Train Loss = 0.0603, Train Acc = 0.9715 | Val Loss = 0.4163, Val Acc = 0.9236
# Epoch 248: Train Loss = 0.0665, Train Acc = 0.9655 | Val Loss = 0.5063, Val Acc = 0.9375
# Epoch 249: Train Loss = 0.0595, Train Acc = 0.9707 | Val Loss = 0.4481, Val Acc = 0.9167
# Epoch 250: Train Loss = 0.0726, Train Acc = 0.9689 | Val Loss = 0.4866, Val Acc = 0.9097
# Epoch 251: Train Loss = 0.1518, Train Acc = 0.9370 | Val Loss = 0.5807, Val Acc = 0.8889
# Epoch 252: Train Loss = 0.1132, Train Acc = 0.9543 | Val Loss = 0.5682, Val Acc = 0.9167
# Epoch 253: Train Loss = 0.0745, Train Acc = 0.9655 | Val Loss = 0.4261, Val Acc = 0.9097
# Epoch 254: Train Loss = 0.0770, Train Acc = 0.9646 | Val Loss = 0.3978, Val Acc = 0.9306
# Epoch 255: Train Loss = 0.0679, Train Acc = 0.9655 | Val Loss = 0.4406, Val Acc = 0.9236
# Epoch 256: Train Loss = 0.0691, Train Acc = 0.9689 | Val Loss = 0.6173, Val Acc = 0.9167
# Epoch 257: Train Loss = 0.0673, Train Acc = 0.9629 | Val Loss = 0.4587, Val Acc = 0.9236
# Epoch 258: Train Loss = 0.0722, Train Acc = 0.9638 | Val Loss = 0.3788, Val Acc = 0.9097
# Epoch 259: Train Loss = 0.0778, Train Acc = 0.9646 | Val Loss = 0.5786, Val Acc = 0.8819
# Epoch 260: Train Loss = 0.0689, Train Acc = 0.9689 | Val Loss = 0.4543, Val Acc = 0.9167
# Epoch 261: Train Loss = 0.0824, Train Acc = 0.9646 | Val Loss = 0.6435, Val Acc = 0.9236
# Epoch 262: Train Loss = 0.0734, Train Acc = 0.9681 | Val Loss = 0.4503, Val Acc = 0.9306
# Epoch 263: Train Loss = 0.0778, Train Acc = 0.9629 | Val Loss = 0.4419, Val Acc = 0.9306
# Epoch 264: Train Loss = 0.0617, Train Acc = 0.9715 | Val Loss = 0.4237, Val Acc = 0.9167
# Epoch 265: Train Loss = 0.0705, Train Acc = 0.9655 | Val Loss = 0.5276, Val Acc = 0.9097
# Epoch 266: Train Loss = 0.0634, Train Acc = 0.9664 | Val Loss = 0.4496, Val Acc = 0.9167
# Epoch 267: Train Loss = 0.0654, Train Acc = 0.9681 | Val Loss = 0.4502, Val Acc = 0.9167
# Epoch 268: Train Loss = 0.0585, Train Acc = 0.9672 | Val Loss = 0.5962, Val Acc = 0.9097
# Epoch 269: Train Loss = 0.0655, Train Acc = 0.9672 | Val Loss = 0.4801, Val Acc = 0.9236
# Epoch 270: Train Loss = 0.0886, Train Acc = 0.9612 | Val Loss = 0.6457, Val Acc = 0.9236
# Epoch 271: Train Loss = 0.0908, Train Acc = 0.9612 | Val Loss = 0.4644, Val Acc = 0.9097
# Epoch 272: Train Loss = 0.1401, Train Acc = 0.9405 | Val Loss = 0.3982, Val Acc = 0.9236
# Epoch 273: Train Loss = 0.0848, Train Acc = 0.9646 | Val Loss = 0.4147, Val Acc = 0.9236
# Epoch 274: Train Loss = 0.0643, Train Acc = 0.9698 | Val Loss = 0.4875, Val Acc = 0.8958
# Epoch 275: Train Loss = 0.0714, Train Acc = 0.9594 | Val Loss = 0.4361, Val Acc = 0.9306
# Epoch 276: Train Loss = 0.0634, Train Acc = 0.9698 | Val Loss = 0.5438, Val Acc = 0.9028
# Epoch 277: Train Loss = 0.0753, Train Acc = 0.9664 | Val Loss = 0.4454, Val Acc = 0.9097
# Epoch 278: Train Loss = 0.0665, Train Acc = 0.9655 | Val Loss = 0.5386, Val Acc = 0.9028
# Epoch 279: Train Loss = 0.0582, Train Acc = 0.9724 | Val Loss = 0.4364, Val Acc = 0.9236
# Epoch 280: Train Loss = 0.0660, Train Acc = 0.9681 | Val Loss = 0.4982, Val Acc = 0.9306
# Epoch 281: Train Loss = 0.0669, Train Acc = 0.9664 | Val Loss = 0.4661, Val Acc = 0.9236
# Epoch 282: Train Loss = 0.0612, Train Acc = 0.9689 | Val Loss = 0.4695, Val Acc = 0.9236
# Epoch 283: Train Loss = 0.0687, Train Acc = 0.9707 | Val Loss = 0.4347, Val Acc = 0.9167
# Epoch 284: Train Loss = 0.0691, Train Acc = 0.9698 | Val Loss = 0.5027, Val Acc = 0.9306
# Epoch 285: Train Loss = 0.0630, Train Acc = 0.9655 | Val Loss = 0.4491, Val Acc = 0.9167
# Epoch 286: Train Loss = 0.0965, Train Acc = 0.9612 | Val Loss = 0.4594, Val Acc = 0.9167
# Epoch 287: Train Loss = 0.1016, Train Acc = 0.9525 | Val Loss = 0.5646, Val Acc = 0.9236
# Epoch 288: Train Loss = 0.0824, Train Acc = 0.9612 | Val Loss = 0.4792, Val Acc = 0.9236
# Epoch 289: Train Loss = 0.0753, Train Acc = 0.9629 | Val Loss = 0.5230, Val Acc = 0.9236
# Epoch 290: Train Loss = 0.0627, Train Acc = 0.9664 | Val Loss = 0.5343, Val Acc = 0.9097
# Epoch 291: Train Loss = 0.0592, Train Acc = 0.9707 | Val Loss = 0.4286, Val Acc = 0.9097
# Epoch 292: Train Loss = 0.0643, Train Acc = 0.9689 | Val Loss = 0.5103, Val Acc = 0.9097
# Epoch 293: Train Loss = 0.0560, Train Acc = 0.9733 | Val Loss = 0.5281, Val Acc = 0.9167
# Epoch 294: Train Loss = 0.0598, Train Acc = 0.9689 | Val Loss = 0.4829, Val Acc = 0.9097
# Epoch 295: Train Loss = 0.0564, Train Acc = 0.9715 | Val Loss = 0.4487, Val Acc = 0.9236
# Epoch 296: Train Loss = 0.0582, Train Acc = 0.9707 | Val Loss = 0.5339, Val Acc = 0.9097
# Epoch 297: Train Loss = 0.0561, Train Acc = 0.9715 | Val Loss = 0.4698, Val Acc = 0.9236
# Epoch 298: Train Loss = 0.0578, Train Acc = 0.9724 | Val Loss = 0.5027, Val Acc = 0.9167
# Epoch 299: Train Loss = 0.0584, Train Acc = 0.9707 | Val Loss = 0.5070, Val Acc = 0.9097
# Epoch 300: Train Loss = 0.0577, Train Acc = 0.9707 | Val Loss = 0.5666, Val Acc = 0.9097
# Epoch 301: Train Loss = 0.0608, Train Acc = 0.9733 | Val Loss = 0.5860, Val Acc = 0.9306
# Epoch 302: Train Loss = 0.0913, Train Acc = 0.9577 | Val Loss = 0.3856, Val Acc = 0.9306
# Epoch 303: Train Loss = 0.1256, Train Acc = 0.9465 | Val Loss = 0.5896, Val Acc = 0.8819
# Epoch 304: Train Loss = 0.0902, Train Acc = 0.9560 | Val Loss = 0.5762, Val Acc = 0.9097
# Epoch 305: Train Loss = 0.0618, Train Acc = 0.9707 | Val Loss = 0.5635, Val Acc = 0.9097
# Epoch 306: Train Loss = 0.0621, Train Acc = 0.9715 | Val Loss = 0.5751, Val Acc = 0.8958
# Epoch 307: Train Loss = 0.0646, Train Acc = 0.9672 | Val Loss = 0.5682, Val Acc = 0.9097
# Epoch 308: Train Loss = 0.0624, Train Acc = 0.9672 | Val Loss = 0.5223, Val Acc = 0.9028
# Epoch 309: Train Loss = 0.0598, Train Acc = 0.9707 | Val Loss = 0.5752, Val Acc = 0.9236
# Epoch 310: Train Loss = 0.0632, Train Acc = 0.9689 | Val Loss = 0.6458, Val Acc = 0.9097
# Epoch 311: Train Loss = 0.0610, Train Acc = 0.9698 | Val Loss = 0.5115, Val Acc = 0.9236
# Epoch 312: Train Loss = 0.0634, Train Acc = 0.9672 | Val Loss = 0.4823, Val Acc = 0.9167
# Epoch 313: Train Loss = 0.0628, Train Acc = 0.9715 | Val Loss = 0.5024, Val Acc = 0.9236
# Epoch 314: Train Loss = 0.0614, Train Acc = 0.9715 | Val Loss = 0.6283, Val Acc = 0.9375
# Epoch 315: Train Loss = 0.0610, Train Acc = 0.9758 | Val Loss = 0.5327, Val Acc = 0.9236
# Epoch 316: Train Loss = 0.0637, Train Acc = 0.9655 | Val Loss = 0.4989, Val Acc = 0.9236
# Epoch 317: Train Loss = 0.0604, Train Acc = 0.9715 | Val Loss = 0.5791, Val Acc = 0.9306
# Epoch 318: Train Loss = 0.0660, Train Acc = 0.9689 | Val Loss = 0.5449, Val Acc = 0.9375
# Epoch 319: Train Loss = 0.0723, Train Acc = 0.9594 | Val Loss = 0.5035, Val Acc = 0.9306
# Epoch 320: Train Loss = 0.1217, Train Acc = 0.9551 | Val Loss = 0.5730, Val Acc = 0.8958
# Epoch 321: Train Loss = 0.0869, Train Acc = 0.9620 | Val Loss = 0.5463, Val Acc = 0.9306
# Epoch 322: Train Loss = 0.0857, Train Acc = 0.9603 | Val Loss = 0.5543, Val Acc = 0.8958
# Epoch 323: Train Loss = 0.0875, Train Acc = 0.9664 | Val Loss = 0.4986, Val Acc = 0.9097
# Epoch 324: Train Loss = 0.0646, Train Acc = 0.9672 | Val Loss = 0.4712, Val Acc = 0.9097
# Epoch 325: Train Loss = 0.0611, Train Acc = 0.9733 | Val Loss = 0.4859, Val Acc = 0.9167
# Epoch 326: Train Loss = 0.0562, Train Acc = 0.9724 | Val Loss = 0.5423, Val Acc = 0.9236
# Epoch 327: Train Loss = 0.0635, Train Acc = 0.9698 | Val Loss = 0.4689, Val Acc = 0.9028
# Epoch 328: Train Loss = 0.0736, Train Acc = 0.9646 | Val Loss = 0.4328, Val Acc = 0.9028
# Epoch 329: Train Loss = 0.0558, Train Acc = 0.9741 | Val Loss = 0.5033, Val Acc = 0.9097
# Epoch 330: Train Loss = 0.0673, Train Acc = 0.9672 | Val Loss = 0.5732, Val Acc = 0.9167
# Epoch 331: Train Loss = 0.0607, Train Acc = 0.9724 | Val Loss = 0.5385, Val Acc = 0.9306
# Epoch 332: Train Loss = 0.0570, Train Acc = 0.9733 | Val Loss = 0.5692, Val Acc = 0.9167
# Epoch 333: Train Loss = 0.0567, Train Acc = 0.9715 | Val Loss = 0.5322, Val Acc = 0.9097
# Epoch 334: Train Loss = 0.0600, Train Acc = 0.9698 | Val Loss = 0.6031, Val Acc = 0.9236
# Epoch 335: Train Loss = 0.0597, Train Acc = 0.9724 | Val Loss = 0.5740, Val Acc = 0.9028
# Epoch 336: Train Loss = 0.0752, Train Acc = 0.9698 | Val Loss = 0.5904, Val Acc = 0.8958
# Epoch 337: Train Loss = 0.0830, Train Acc = 0.9707 | Val Loss = 0.4944, Val Acc = 0.9028
# Epoch 338: Train Loss = 0.1124, Train Acc = 0.9551 | Val Loss = 0.6168, Val Acc = 0.9097
# Epoch 339: Train Loss = 0.0855, Train Acc = 0.9638 | Val Loss = 0.4587, Val Acc = 0.9097
# Epoch 340: Train Loss = 0.0637, Train Acc = 0.9698 | Val Loss = 0.5455, Val Acc = 0.9236
# Epoch 341: Train Loss = 0.0690, Train Acc = 0.9715 | Val Loss = 0.5465, Val Acc = 0.9097
# Epoch 342: Train Loss = 0.0646, Train Acc = 0.9689 | Val Loss = 0.4946, Val Acc = 0.9097
# Epoch 343: Train Loss = 0.0630, Train Acc = 0.9672 | Val Loss = 0.5678, Val Acc = 0.9097
# Epoch 344: Train Loss = 0.0597, Train Acc = 0.9698 | Val Loss = 0.5125, Val Acc = 0.9375
# Epoch 345: Train Loss = 0.0630, Train Acc = 0.9733 | Val Loss = 0.5616, Val Acc = 0.9097
# Epoch 346: Train Loss = 0.0634, Train Acc = 0.9664 | Val Loss = 0.5054, Val Acc = 0.9306
# Epoch 347: Train Loss = 0.0588, Train Acc = 0.9724 | Val Loss = 0.5949, Val Acc = 0.9236
# Epoch 348: Train Loss = 0.0659, Train Acc = 0.9664 | Val Loss = 0.5900, Val Acc = 0.9028
# Epoch 349: Train Loss = 0.0602, Train Acc = 0.9655 | Val Loss = 0.6484, Val Acc = 0.9236
# Epoch 350: Train Loss = 0.0596, Train Acc = 0.9707 | Val Loss = 0.4225, Val Acc = 0.9444
# Epoch 351: Train Loss = 0.0674, Train Acc = 0.9715 | Val Loss = 0.5631, Val Acc = 0.9167
# Epoch 352: Train Loss = 0.0629, Train Acc = 0.9698 | Val Loss = 0.5762, Val Acc = 0.9028
# Epoch 353: Train Loss = 0.0564, Train Acc = 0.9741 | Val Loss = 0.5120, Val Acc = 0.9097
# Epoch 354: Train Loss = 0.0666, Train Acc = 0.9715 | Val Loss = 0.6197, Val Acc = 0.9306
# Epoch 355: Train Loss = 0.0772, Train Acc = 0.9603 | Val Loss = 0.4908, Val Acc = 0.9097
# Epoch 356: Train Loss = 0.0662, Train Acc = 0.9655 | Val Loss = 0.5208, Val Acc = 0.9306
# Epoch 357: Train Loss = 0.0631, Train Acc = 0.9655 | Val Loss = 0.5257, Val Acc = 0.9167
# Epoch 358: Train Loss = 0.1067, Train Acc = 0.9534 | Val Loss = 0.6368, Val Acc = 0.9236
# Epoch 359: Train Loss = 0.0889, Train Acc = 0.9612 | Val Loss = 0.5219, Val Acc = 0.9028
# Epoch 360: Train Loss = 0.0673, Train Acc = 0.9664 | Val Loss = 0.4670, Val Acc = 0.9236
# Epoch 361: Train Loss = 0.0656, Train Acc = 0.9655 | Val Loss = 0.5598, Val Acc = 0.9306
# Epoch 362: Train Loss = 0.0657, Train Acc = 0.9655 | Val Loss = 0.5602, Val Acc = 0.9167
# Epoch 363: Train Loss = 0.0631, Train Acc = 0.9698 | Val Loss = 0.5109, Val Acc = 0.9306
# Epoch 364: Train Loss = 0.0578, Train Acc = 0.9689 | Val Loss = 0.5458, Val Acc = 0.9236
# Epoch 365: Train Loss = 0.0543, Train Acc = 0.9715 | Val Loss = 0.6048, Val Acc = 0.9236
# Epoch 366: Train Loss = 0.0602, Train Acc = 0.9707 | Val Loss = 0.5674, Val Acc = 0.9236
# Epoch 367: Train Loss = 0.0598, Train Acc = 0.9698 | Val Loss = 0.5614, Val Acc = 0.9375
# Epoch 368: Train Loss = 0.0630, Train Acc = 0.9664 | Val Loss = 0.5919, Val Acc = 0.9167
# Epoch 369: Train Loss = 0.0617, Train Acc = 0.9698 | Val Loss = 0.6433, Val Acc = 0.9236
# Epoch 370: Train Loss = 0.0654, Train Acc = 0.9698 | Val Loss = 0.5712, Val Acc = 0.9236
# Epoch 371: Train Loss = 0.0605, Train Acc = 0.9724 | Val Loss = 0.4691, Val Acc = 0.9167
# Epoch 372: Train Loss = 0.0586, Train Acc = 0.9655 | Val Loss = 0.5269, Val Acc = 0.9375
# Epoch 373: Train Loss = 0.0646, Train Acc = 0.9698 | Val Loss = 0.6454, Val Acc = 0.9236
# Epoch 374: Train Loss = 0.0672, Train Acc = 0.9698 | Val Loss = 0.5614, Val Acc = 0.9097
# Epoch 375: Train Loss = 0.0679, Train Acc = 0.9715 | Val Loss = 0.6893, Val Acc = 0.9167
# Epoch 376: Train Loss = 0.0778, Train Acc = 0.9672 | Val Loss = 0.5629, Val Acc = 0.9097
# Epoch 377: Train Loss = 0.0846, Train Acc = 0.9629 | Val Loss = 0.7407, Val Acc = 0.9236
# Epoch 378: Train Loss = 0.0807, Train Acc = 0.9620 | Val Loss = 0.5425, Val Acc = 0.9097
# Epoch 379: Train Loss = 0.0831, Train Acc = 0.9620 | Val Loss = 0.6219, Val Acc = 0.9306
# Epoch 380: Train Loss = 0.0723, Train Acc = 0.9664 | Val Loss = 0.4925, Val Acc = 0.9236
# Epoch 381: Train Loss = 0.0583, Train Acc = 0.9750 | Val Loss = 0.4946, Val Acc = 0.9167
# Epoch 382: Train Loss = 0.0649, Train Acc = 0.9724 | Val Loss = 0.5589, Val Acc = 0.9306
# Epoch 383: Train Loss = 0.0634, Train Acc = 0.9689 | Val Loss = 0.5516, Val Acc = 0.9236
# Epoch 384: Train Loss = 0.0603, Train Acc = 0.9724 | Val Loss = 0.5350, Val Acc = 0.9306
# Epoch 385: Train Loss = 0.0582, Train Acc = 0.9689 | Val Loss = 0.6057, Val Acc = 0.9236
# Epoch 386: Train Loss = 0.0541, Train Acc = 0.9698 | Val Loss = 0.5714, Val Acc = 0.9236
# Epoch 387: Train Loss = 0.0528, Train Acc = 0.9724 | Val Loss = 0.6338, Val Acc = 0.9236
# Epoch 388: Train Loss = 0.0640, Train Acc = 0.9672 | Val Loss = 0.5982, Val Acc = 0.9236
# Epoch 389: Train Loss = 0.0617, Train Acc = 0.9698 | Val Loss = 0.4857, Val Acc = 0.9375
# Epoch 390: Train Loss = 0.0531, Train Acc = 0.9715 | Val Loss = 0.5288, Val Acc = 0.9375
# Epoch 391: Train Loss = 0.0612, Train Acc = 0.9672 | Val Loss = 0.4859, Val Acc = 0.9306
# Epoch 392: Train Loss = 0.0748, Train Acc = 0.9655 | Val Loss = 0.5004, Val Acc = 0.9167
# Epoch 393: Train Loss = 0.0589, Train Acc = 0.9724 | Val Loss = 0.5588, Val Acc = 0.9444
# Epoch 394: Train Loss = 0.0770, Train Acc = 0.9672 | Val Loss = 0.6341, Val Acc = 0.9236
# Epoch 395: Train Loss = 0.0693, Train Acc = 0.9715 | Val Loss = 0.5880, Val Acc = 0.9236
# Epoch 396: Train Loss = 0.0706, Train Acc = 0.9681 | Val Loss = 0.6272, Val Acc = 0.9097
# Epoch 397: Train Loss = 0.0651, Train Acc = 0.9681 | Val Loss = 0.6776, Val Acc = 0.9236
# Epoch 398: Train Loss = 0.0675, Train Acc = 0.9689 | Val Loss = 0.5463, Val Acc = 0.8889
# Epoch 399: Train Loss = 0.0616, Train Acc = 0.9655 | Val Loss = 0.6372, Val Acc = 0.9236
# Epoch 400: Train Loss = 0.0850, Train Acc = 0.9594 | Val Loss = 0.5497, Val Acc = 0.9306
# Epoch 401: Train Loss = 0.0725, Train Acc = 0.9655 | Val Loss = 0.6469, Val Acc = 0.9028
# Epoch 402: Train Loss = 0.0885, Train Acc = 0.9603 | Val Loss = 0.8665, Val Acc = 0.8681
# Epoch 403: Train Loss = 0.0914, Train Acc = 0.9629 | Val Loss = 0.5018, Val Acc = 0.8958
# Epoch 404: Train Loss = 0.0828, Train Acc = 0.9646 | Val Loss = 0.4595, Val Acc = 0.9097
# Epoch 405: Train Loss = 0.1081, Train Acc = 0.9500 | Val Loss = 0.7980, Val Acc = 0.8958
# Epoch 406: Train Loss = 0.1433, Train Acc = 0.9448 | Val Loss = 0.6001, Val Acc = 0.9306
# Epoch 407: Train Loss = 0.0650, Train Acc = 0.9689 | Val Loss = 0.5482, Val Acc = 0.9375
# Epoch 408: Train Loss = 0.0599, Train Acc = 0.9698 | Val Loss = 0.5732, Val Acc = 0.9236
# Epoch 409: Train Loss = 0.0668, Train Acc = 0.9689 | Val Loss = 0.6043, Val Acc = 0.9097
# Epoch 410: Train Loss = 0.0626, Train Acc = 0.9664 | Val Loss = 0.5490, Val Acc = 0.9306
# Epoch 411: Train Loss = 0.0536, Train Acc = 0.9724 | Val Loss = 0.5501, Val Acc = 0.9375
# Epoch 412: Train Loss = 0.0532, Train Acc = 0.9776 | Val Loss = 0.5578, Val Acc = 0.9236
# Epoch 413: Train Loss = 0.0521, Train Acc = 0.9733 | Val Loss = 0.5131, Val Acc = 0.9167
# Epoch 414: Train Loss = 0.0568, Train Acc = 0.9715 | Val Loss = 0.5588, Val Acc = 0.9167
# Epoch 415: Train Loss = 0.0550, Train Acc = 0.9733 | Val Loss = 0.6170, Val Acc = 0.9028
# Epoch 416: Train Loss = 0.0579, Train Acc = 0.9715 | Val Loss = 0.6054, Val Acc = 0.9097
# Epoch 417: Train Loss = 0.0599, Train Acc = 0.9750 | Val Loss = 0.6067, Val Acc = 0.9306
# Epoch 418: Train Loss = 0.0652, Train Acc = 0.9629 | Val Loss = 0.5428, Val Acc = 0.9167
# Epoch 419: Train Loss = 0.0543, Train Acc = 0.9724 | Val Loss = 0.5596, Val Acc = 0.9236
# Epoch 420: Train Loss = 0.0582, Train Acc = 0.9733 | Val Loss = 0.4987, Val Acc = 0.9306
# Epoch 421: Train Loss = 0.0591, Train Acc = 0.9707 | Val Loss = 0.5493, Val Acc = 0.9236
# Epoch 422: Train Loss = 0.0583, Train Acc = 0.9724 | Val Loss = 0.5147, Val Acc = 0.9306
# Epoch 423: Train Loss = 0.0563, Train Acc = 0.9707 | Val Loss = 0.5711, Val Acc = 0.9167
# Epoch 424: Train Loss = 0.0563, Train Acc = 0.9707 | Val Loss = 0.5727, Val Acc = 0.9236
# Epoch 425: Train Loss = 0.0538, Train Acc = 0.9741 | Val Loss = 0.5920, Val Acc = 0.9236
# Epoch 426: Train Loss = 0.0592, Train Acc = 0.9724 | Val Loss = 0.6816, Val Acc = 0.9028
# Epoch 427: Train Loss = 0.0589, Train Acc = 0.9741 | Val Loss = 0.5322, Val Acc = 0.9167
# Epoch 428: Train Loss = 0.0640, Train Acc = 0.9681 | Val Loss = 0.6811, Val Acc = 0.9306
# Epoch 429: Train Loss = 0.0596, Train Acc = 0.9733 | Val Loss = 0.7004, Val Acc = 0.9097
# Epoch 430: Train Loss = 0.0594, Train Acc = 0.9733 | Val Loss = 0.6369, Val Acc = 0.9028
# Epoch 431: Train Loss = 0.0717, Train Acc = 0.9603 | Val Loss = 0.6250, Val Acc = 0.9236
# Epoch 432: Train Loss = 0.0679, Train Acc = 0.9698 | Val Loss = 0.6011, Val Acc = 0.9236
# Epoch 433: Train Loss = 0.0673, Train Acc = 0.9646 | Val Loss = 0.7189, Val Acc = 0.9028
# Epoch 434: Train Loss = 0.0541, Train Acc = 0.9758 | Val Loss = 0.6247, Val Acc = 0.9028
# Epoch 435: Train Loss = 0.0641, Train Acc = 0.9672 | Val Loss = 0.7447, Val Acc = 0.9167
# Epoch 436: Train Loss = 0.0649, Train Acc = 0.9672 | Val Loss = 0.6519, Val Acc = 0.9306
# Epoch 437: Train Loss = 0.0696, Train Acc = 0.9629 | Val Loss = 0.6680, Val Acc = 0.9236
# Epoch 438: Train Loss = 0.0754, Train Acc = 0.9672 | Val Loss = 0.6916, Val Acc = 0.9097
# Epoch 439: Train Loss = 0.0813, Train Acc = 0.9655 | Val Loss = 0.7063, Val Acc = 0.9028
# Epoch 440: Train Loss = 0.0746, Train Acc = 0.9681 | Val Loss = 0.5458, Val Acc = 0.9167
# Epoch 441: Train Loss = 0.0681, Train Acc = 0.9655 | Val Loss = 0.7550, Val Acc = 0.9236
# Epoch 442: Train Loss = 0.0831, Train Acc = 0.9689 | Val Loss = 0.8458, Val Acc = 0.8819
# Epoch 443: Train Loss = 0.0842, Train Acc = 0.9629 | Val Loss = 0.5269, Val Acc = 0.9167
# Epoch 444: Train Loss = 0.0611, Train Acc = 0.9733 | Val Loss = 0.6122, Val Acc = 0.9028
# Epoch 445: Train Loss = 0.0650, Train Acc = 0.9689 | Val Loss = 0.5524, Val Acc = 0.9375
# Epoch 446: Train Loss = 0.0590, Train Acc = 0.9758 | Val Loss = 0.6189, Val Acc = 0.9236
# Epoch 447: Train Loss = 0.0575, Train Acc = 0.9715 | Val Loss = 0.5653, Val Acc = 0.9306
# Epoch 448: Train Loss = 0.0583, Train Acc = 0.9689 | Val Loss = 0.5906, Val Acc = 0.9167
# Epoch 449: Train Loss = 0.0502, Train Acc = 0.9724 | Val Loss = 0.5496, Val Acc = 0.9097
# Epoch 450: Train Loss = 0.0561, Train Acc = 0.9715 | Val Loss = 0.6231, Val Acc = 0.9236
# Epoch 451: Train Loss = 0.0535, Train Acc = 0.9741 | Val Loss = 0.6230, Val Acc = 0.9306
# Epoch 452: Train Loss = 0.0540, Train Acc = 0.9733 | Val Loss = 0.5594, Val Acc = 0.9236
# Epoch 453: Train Loss = 0.0511, Train Acc = 0.9758 | Val Loss = 0.6356, Val Acc = 0.9097
# Epoch 454: Train Loss = 0.0576, Train Acc = 0.9758 | Val Loss = 0.5685, Val Acc = 0.9097
# Epoch 455: Train Loss = 0.0555, Train Acc = 0.9733 | Val Loss = 0.5746, Val Acc = 0.9097
# Epoch 456: Train Loss = 0.0601, Train Acc = 0.9715 | Val Loss = 0.4509, Val Acc = 0.9306
# Epoch 457: Train Loss = 0.0622, Train Acc = 0.9715 | Val Loss = 0.5843, Val Acc = 0.9097
# Epoch 458: Train Loss = 0.0604, Train Acc = 0.9698 | Val Loss = 0.6401, Val Acc = 0.9306
# Epoch 459: Train Loss = 0.0571, Train Acc = 0.9750 | Val Loss = 0.5918, Val Acc = 0.9167
# Epoch 460: Train Loss = 0.0522, Train Acc = 0.9715 | Val Loss = 0.4743, Val Acc = 0.9028
# Epoch 461: Train Loss = 0.0587, Train Acc = 0.9689 | Val Loss = 0.7109, Val Acc = 0.9097
# Epoch 462: Train Loss = 0.0614, Train Acc = 0.9715 | Val Loss = 0.6844, Val Acc = 0.9097
# Epoch 463: Train Loss = 0.0573, Train Acc = 0.9681 | Val Loss = 0.6496, Val Acc = 0.9167
# Epoch 464: Train Loss = 0.0653, Train Acc = 0.9724 | Val Loss = 0.7100, Val Acc = 0.8958
# Epoch 465: Train Loss = 0.1188, Train Acc = 0.9508 | Val Loss = 0.6063, Val Acc = 0.9097
# Epoch 466: Train Loss = 0.0739, Train Acc = 0.9620 | Val Loss = 0.7425, Val Acc = 0.9236
# Epoch 467: Train Loss = 0.0625, Train Acc = 0.9715 | Val Loss = 0.5654, Val Acc = 0.9028
# Epoch 468: Train Loss = 0.0665, Train Acc = 0.9707 | Val Loss = 0.5015, Val Acc = 0.9167
# Epoch 469: Train Loss = 0.0594, Train Acc = 0.9715 | Val Loss = 0.7458, Val Acc = 0.9167
# Epoch 470: Train Loss = 0.0591, Train Acc = 0.9698 | Val Loss = 0.6746, Val Acc = 0.9236
# Epoch 471: Train Loss = 0.0626, Train Acc = 0.9698 | Val Loss = 0.5879, Val Acc = 0.9097
# Epoch 472: Train Loss = 0.0706, Train Acc = 0.9681 | Val Loss = 0.5158, Val Acc = 0.9236
# Epoch 473: Train Loss = 0.0852, Train Acc = 0.9594 | Val Loss = 0.6459, Val Acc = 0.9097
# Epoch 474: Train Loss = 0.0899, Train Acc = 0.9594 | Val Loss = 0.6407, Val Acc = 0.9097
# Epoch 475: Train Loss = 0.0877, Train Acc = 0.9612 | Val Loss = 0.7052, Val Acc = 0.9306
# Epoch 476: Train Loss = 0.0720, Train Acc = 0.9681 | Val Loss = 0.5580, Val Acc = 0.9236
# Epoch 477: Train Loss = 0.0702, Train Acc = 0.9681 | Val Loss = 0.5025, Val Acc = 0.9375
# Epoch 478: Train Loss = 0.0622, Train Acc = 0.9707 | Val Loss = 0.6204, Val Acc = 0.9097
# Epoch 479: Train Loss = 0.0566, Train Acc = 0.9767 | Val Loss = 0.6844, Val Acc = 0.9097
# Epoch 480: Train Loss = 0.0571, Train Acc = 0.9707 | Val Loss = 0.5848, Val Acc = 0.9375
# Epoch 481: Train Loss = 0.0532, Train Acc = 0.9715 | Val Loss = 0.7531, Val Acc = 0.9167
# Epoch 482: Train Loss = 0.0557, Train Acc = 0.9724 | Val Loss = 0.6626, Val Acc = 0.9097
# Epoch 483: Train Loss = 0.0509, Train Acc = 0.9724 | Val Loss = 0.6976, Val Acc = 0.9167
# Epoch 484: Train Loss = 0.0540, Train Acc = 0.9707 | Val Loss = 0.6769, Val Acc = 0.9028
# Epoch 485: Train Loss = 0.0551, Train Acc = 0.9715 | Val Loss = 0.7055, Val Acc = 0.9097
# Epoch 486: Train Loss = 0.0554, Train Acc = 0.9707 | Val Loss = 0.5760, Val Acc = 0.9236
# Epoch 487: Train Loss = 0.0530, Train Acc = 0.9750 | Val Loss = 0.5907, Val Acc = 0.9306
# Epoch 488: Train Loss = 0.0545, Train Acc = 0.9715 | Val Loss = 0.6382, Val Acc = 0.9375
# Epoch 489: Train Loss = 0.0554, Train Acc = 0.9707 | Val Loss = 0.5905, Val Acc = 0.9097
# Epoch 490: Train Loss = 0.0529, Train Acc = 0.9758 | Val Loss = 0.6377, Val Acc = 0.9306
# Epoch 491: Train Loss = 0.0545, Train Acc = 0.9698 | Val Loss = 0.6787, Val Acc = 0.9306
# Epoch 492: Train Loss = 0.0576, Train Acc = 0.9724 | Val Loss = 0.6792, Val Acc = 0.9306
# Epoch 493: Train Loss = 0.0532, Train Acc = 0.9741 | Val Loss = 0.7699, Val Acc = 0.9236
# Epoch 494: Train Loss = 0.0564, Train Acc = 0.9646 | Val Loss = 0.5534, Val Acc = 0.9097
# Epoch 495: Train Loss = 0.0576, Train Acc = 0.9698 | Val Loss = 0.5382, Val Acc = 0.9097
# Epoch 496: Train Loss = 0.0690, Train Acc = 0.9672 | Val Loss = 0.7500, Val Acc = 0.9167
# Epoch 497: Train Loss = 0.0943, Train Acc = 0.9655 | Val Loss = 0.9425, Val Acc = 0.8958
# Epoch 498: Train Loss = 0.0783, Train Acc = 0.9698 | Val Loss = 0.6914, Val Acc = 0.9236
# Epoch 499: Train Loss = 0.0653, Train Acc = 0.9715 | Val Loss = 0.8912, Val Acc = 0.9097
# Epoch 500: Train Loss = 0.0624, Train Acc = 0.9733 | Val Loss = 0.7395, Val Acc = 0.9028
# Epoch 501: Train Loss = 0.0732, Train Acc = 0.9646 | Val Loss = 0.7314, Val Acc = 0.8819
# Epoch 502: Train Loss = 0.0911, Train Acc = 0.9560 | Val Loss = 0.6920, Val Acc = 0.9028
# Epoch 503: Train Loss = 0.0792, Train Acc = 0.9638 | Val Loss = 0.7000, Val Acc = 0.9097
# Epoch 504: Train Loss = 0.0674, Train Acc = 0.9698 | Val Loss = 0.5571, Val Acc = 0.9236
# Epoch 505: Train Loss = 0.0595, Train Acc = 0.9715 | Val Loss = 0.5739, Val Acc = 0.9236
# Epoch 506: Train Loss = 0.0591, Train Acc = 0.9715 | Val Loss = 0.5811, Val Acc = 0.9306
# Epoch 507: Train Loss = 0.0601, Train Acc = 0.9733 | Val Loss = 0.5970, Val Acc = 0.9097
# Epoch 508: Train Loss = 0.0617, Train Acc = 0.9707 | Val Loss = 0.6386, Val Acc = 0.9097
# Epoch 509: Train Loss = 0.0527, Train Acc = 0.9724 | Val Loss = 0.6162, Val Acc = 0.9306
# Epoch 510: Train Loss = 0.0510, Train Acc = 0.9741 | Val Loss = 0.5681, Val Acc = 0.9375
# Epoch 511: Train Loss = 0.0596, Train Acc = 0.9698 | Val Loss = 0.7635, Val Acc = 0.9097
# Epoch 512: Train Loss = 0.0649, Train Acc = 0.9698 | Val Loss = 0.7374, Val Acc = 0.9236
# Epoch 513: Train Loss = 0.0594, Train Acc = 0.9741 | Val Loss = 0.6602, Val Acc = 0.8958
# Epoch 514: Train Loss = 0.0550, Train Acc = 0.9767 | Val Loss = 0.7592, Val Acc = 0.9167
# Epoch 515: Train Loss = 0.0531, Train Acc = 0.9750 | Val Loss = 0.5563, Val Acc = 0.9236
# Epoch 516: Train Loss = 0.0540, Train Acc = 0.9646 | Val Loss = 0.6786, Val Acc = 0.9236
# Epoch 517: Train Loss = 0.0548, Train Acc = 0.9767 | Val Loss = 0.6615, Val Acc = 0.9167
# Epoch 518: Train Loss = 0.0503, Train Acc = 0.9750 | Val Loss = 0.6210, Val Acc = 0.9167
# Epoch 519: Train Loss = 0.0530, Train Acc = 0.9741 | Val Loss = 0.5329, Val Acc = 0.9167
# Epoch 520: Train Loss = 0.0539, Train Acc = 0.9698 | Val Loss = 0.6357, Val Acc = 0.9097
# Epoch 521: Train Loss = 0.0543, Train Acc = 0.9698 | Val Loss = 0.6232, Val Acc = 0.9306
# Epoch 522: Train Loss = 0.0570, Train Acc = 0.9707 | Val Loss = 0.6727, Val Acc = 0.9097
# Epoch 523: Train Loss = 0.0605, Train Acc = 0.9698 | Val Loss = 0.6845, Val Acc = 0.9167
# Epoch 524: Train Loss = 0.0668, Train Acc = 0.9689 | Val Loss = 0.6663, Val Acc = 0.9097
# Epoch 525: Train Loss = 0.0525, Train Acc = 0.9698 | Val Loss = 0.7117, Val Acc = 0.9097
# Epoch 526: Train Loss = 0.0552, Train Acc = 0.9698 | Val Loss = 0.7441, Val Acc = 0.9236
# Epoch 527: Train Loss = 0.0556, Train Acc = 0.9715 | Val Loss = 0.6075, Val Acc = 0.9375
# Epoch 528: Train Loss = 0.0995, Train Acc = 0.9543 | Val Loss = 0.7008, Val Acc = 0.9028
# Epoch 529: Train Loss = 0.1491, Train Acc = 0.9474 | Val Loss = 0.8506, Val Acc = 0.9306
# Epoch 530: Train Loss = 0.0869, Train Acc = 0.9638 | Val Loss = 0.5049, Val Acc = 0.9167
# Epoch 531: Train Loss = 0.0793, Train Acc = 0.9646 | Val Loss = 0.6914, Val Acc = 0.9167
# Epoch 532: Train Loss = 0.0595, Train Acc = 0.9707 | Val Loss = 0.7052, Val Acc = 0.9167
# Epoch 533: Train Loss = 0.0644, Train Acc = 0.9681 | Val Loss = 0.5659, Val Acc = 0.9097
# Epoch 534: Train Loss = 0.0499, Train Acc = 0.9741 | Val Loss = 0.6693, Val Acc = 0.9236
# Epoch 535: Train Loss = 0.0581, Train Acc = 0.9689 | Val Loss = 0.7441, Val Acc = 0.9236
# Epoch 536: Train Loss = 0.0527, Train Acc = 0.9707 | Val Loss = 0.7693, Val Acc = 0.9167
# Epoch 537: Train Loss = 0.0529, Train Acc = 0.9724 | Val Loss = 0.6198, Val Acc = 0.9167
# Epoch 538: Train Loss = 0.0473, Train Acc = 0.9767 | Val Loss = 0.5350, Val Acc = 0.9375
# Epoch 539: Train Loss = 0.0607, Train Acc = 0.9715 | Val Loss = 0.6886, Val Acc = 0.9167
# Epoch 540: Train Loss = 0.0570, Train Acc = 0.9698 | Val Loss = 0.6353, Val Acc = 0.9167
# ...
# Epoch 822: Train Loss = 0.0546, Train Acc = 0.9741 | Val Loss = 0.7226, Val Acc = 0.9236
# Epoch 823: Train Loss = 0.0499, Train Acc = 0.9776 | Val Loss = 0.7554, Val Acc = 0.9236
# Epoch 824: Train Loss = 0.0539, Train Acc = 0.9689 | Val Loss = 0.7765, Val Acc = 0.9167
# Epoch 825: Train Loss = 0.0529, Train Acc = 0.9750 | Val Loss = 0.6752, Val Acc = 0.9236
# Epoch 826: Train Loss = 0.0527, Train Acc = 0.9715 | Val Loss = 0.6173, Val Acc = 0.9236
# Epoch 827: Train Loss = 0.0528, Train Acc = 0.9698 | Val Loss = 0.7268, Val Acc = 0.9236
# Epoch 828: Train Loss = 0.0515, Train Acc = 0.9750 | Val Loss = 0.7561, Val Acc = 0.9236
# Epoch 829: Train Loss = 0.0533, Train Acc = 0.9715 | Val Loss = 0.8030, Val Acc = 0.9097
# Epoch 830: Train Loss = 0.0505, Train Acc = 0.9733 | Val Loss = 0.8101, Val Acc = 0.9306
# Epoch 831: Train Loss = 0.0550, Train Acc = 0.9707 | Val Loss = 0.6567, Val Acc = 0.9167
# Epoch 832: Train Loss = 0.0529, Train Acc = 0.9741 | Val Loss = 0.7268, Val Acc = 0.9306
# Epoch 833: Train Loss = 0.0631, Train Acc = 0.9707 | Val Loss = 0.6869, Val Acc = 0.9028
# Epoch 834: Train Loss = 0.0602, Train Acc = 0.9646 | Val Loss = 0.7353, Val Acc = 0.9167
# Epoch 835: Train Loss = 0.0581, Train Acc = 0.9689 | Val Loss = 0.5780, Val Acc = 0.9375
# Epoch 836: Train Loss = 0.0577, Train Acc = 0.9750 | Val Loss = 0.6944, Val Acc = 0.9306
# Epoch 837: Train Loss = 0.0544, Train Acc = 0.9776 | Val Loss = 0.6884, Val Acc = 0.9306
# Epoch 838: Train Loss = 0.0508, Train Acc = 0.9724 | Val Loss = 0.7151, Val Acc = 0.9167
# Epoch 839: Train Loss = 0.0615, Train Acc = 0.9741 | Val Loss = 0.7748, Val Acc = 0.9236
# Epoch 840: Train Loss = 0.0606, Train Acc = 0.9724 | Val Loss = 0.6689, Val Acc = 0.9236
# Epoch 841: Train Loss = 0.0508, Train Acc = 0.9741 | Val Loss = 0.7636, Val Acc = 0.9167
# Epoch 842: Train Loss = 0.0498, Train Acc = 0.9741 | Val Loss = 0.8634, Val Acc = 0.9097
# Epoch 843: Train Loss = 0.0612, Train Acc = 0.9689 | Val Loss = 0.7166, Val Acc = 0.9097
# Epoch 844: Train Loss = 0.0493, Train Acc = 0.9715 | Val Loss = 0.7186, Val Acc = 0.9028
# Epoch 845: Train Loss = 0.0542, Train Acc = 0.9698 | Val Loss = 0.7565, Val Acc = 0.9236
# Epoch 846: Train Loss = 0.0542, Train Acc = 0.9758 | Val Loss = 0.7377, Val Acc = 0.9097
# Epoch 847: Train Loss = 0.0542, Train Acc = 0.9707 | Val Loss = 0.8117, Val Acc = 0.9028
# Epoch 848: Train Loss = 0.0635, Train Acc = 0.9689 | Val Loss = 0.6212, Val Acc = 0.9167
# Epoch 849: Train Loss = 0.0511, Train Acc = 0.9689 | Val Loss = 0.5469, Val Acc = 0.9306
# Epoch 850: Train Loss = 0.0503, Train Acc = 0.9715 | Val Loss = 0.7930, Val Acc = 0.9167
# Epoch 851: Train Loss = 0.0711, Train Acc = 0.9715 | Val Loss = 0.6348, Val Acc = 0.9236
# Epoch 852: Train Loss = 0.0647, Train Acc = 0.9672 | Val Loss = 1.0459, Val Acc = 0.9028
# Epoch 853: Train Loss = 0.0687, Train Acc = 0.9664 | Val Loss = 0.7851, Val Acc = 0.9236
# Epoch 854: Train Loss = 0.0907, Train Acc = 0.9603 | Val Loss = 0.9500, Val Acc = 0.9167
# Epoch 855: Train Loss = 0.0566, Train Acc = 0.9733 | Val Loss = 0.8203, Val Acc = 0.9236
# Epoch 856: Train Loss = 0.0658, Train Acc = 0.9698 | Val Loss = 0.8730, Val Acc = 0.9028
# Epoch 857: Train Loss = 0.0606, Train Acc = 0.9724 | Val Loss = 0.7779, Val Acc = 0.9236
# Epoch 858: Train Loss = 0.0536, Train Acc = 0.9681 | Val Loss = 0.7509, Val Acc = 0.9167
# Epoch 859: Train Loss = 0.0636, Train Acc = 0.9698 | Val Loss = 0.7790, Val Acc = 0.9236
# Epoch 860: Train Loss = 0.0536, Train Acc = 0.9724 | Val Loss = 0.7361, Val Acc = 0.9028
# Epoch 861: Train Loss = 0.0463, Train Acc = 0.9750 | Val Loss = 0.7531, Val Acc = 0.9236
# Epoch 862: Train Loss = 0.0560, Train Acc = 0.9724 | Val Loss = 0.5508, Val Acc = 0.9514
# Epoch 863: Train Loss = 0.0454, Train Acc = 0.9776 | Val Loss = 0.7214, Val Acc = 0.9167
# Epoch 864: Train Loss = 0.0491, Train Acc = 0.9750 | Val Loss = 0.6817, Val Acc = 0.9236
# Epoch 865: Train Loss = 0.0731, Train Acc = 0.9681 | Val Loss = 0.7229, Val Acc = 0.9375
# Epoch 866: Train Loss = 0.0626, Train Acc = 0.9698 | Val Loss = 0.7940, Val Acc = 0.9167
# Epoch 867: Train Loss = 0.0506, Train Acc = 0.9767 | Val Loss = 0.7432, Val Acc = 0.9375
# Epoch 868: Train Loss = 0.0537, Train Acc = 0.9698 | Val Loss = 0.6549, Val Acc = 0.9375
# Epoch 869: Train Loss = 0.0490, Train Acc = 0.9750 | Val Loss = 0.7098, Val Acc = 0.9306
# Epoch 870: Train Loss = 0.0679, Train Acc = 0.9681 | Val Loss = 0.7823, Val Acc = 0.9375
# Epoch 871: Train Loss = 0.0618, Train Acc = 0.9689 | Val Loss = 0.8088, Val Acc = 0.9167
# Epoch 872: Train Loss = 0.0582, Train Acc = 0.9741 | Val Loss = 0.7533, Val Acc = 0.9236
# Epoch 873: Train Loss = 0.0572, Train Acc = 0.9715 | Val Loss = 0.8189, Val Acc = 0.9236
# Epoch 874: Train Loss = 0.0508, Train Acc = 0.9733 | Val Loss = 0.9807, Val Acc = 0.9028
# Epoch 875: Train Loss = 0.0512, Train Acc = 0.9733 | Val Loss = 0.7683, Val Acc = 0.9167
# Epoch 876: Train Loss = 0.0532, Train Acc = 0.9767 | Val Loss = 0.7683, Val Acc = 0.9097
# Epoch 877: Train Loss = 0.0521, Train Acc = 0.9758 | Val Loss = 0.7763, Val Acc = 0.9236
# Epoch 878: Train Loss = 0.0525, Train Acc = 0.9724 | Val Loss = 0.8008, Val Acc = 0.9167
# Epoch 879: Train Loss = 0.0585, Train Acc = 0.9724 | Val Loss = 0.8949, Val Acc = 0.9236
# Epoch 880: Train Loss = 0.0468, Train Acc = 0.9767 | Val Loss = 0.8392, Val Acc = 0.9097
# Epoch 881: Train Loss = 0.0527, Train Acc = 0.9715 | Val Loss = 0.8301, Val Acc = 0.9028
# Epoch 882: Train Loss = 0.0485, Train Acc = 0.9758 | Val Loss = 0.8515, Val Acc = 0.9167
# Epoch 883: Train Loss = 0.0521, Train Acc = 0.9767 | Val Loss = 0.7967, Val Acc = 0.9167
# Epoch 884: Train Loss = 0.0509, Train Acc = 0.9758 | Val Loss = 0.8425, Val Acc = 0.9236
# Epoch 885: Train Loss = 0.0534, Train Acc = 0.9724 | Val Loss = 0.8451, Val Acc = 0.9167
# Epoch 886: Train Loss = 0.0511, Train Acc = 0.9784 | Val Loss = 0.8746, Val Acc = 0.9167
# Epoch 887: Train Loss = 0.0711, Train Acc = 0.9715 | Val Loss = 0.9224, Val Acc = 0.9167
# Epoch 888: Train Loss = 0.0926, Train Acc = 0.9620 | Val Loss = 0.8331, Val Acc = 0.9167
# Epoch 889: Train Loss = 0.0703, Train Acc = 0.9672 | Val Loss = 0.7349, Val Acc = 0.9028
# Epoch 890: Train Loss = 0.0604, Train Acc = 0.9689 | Val Loss = 0.9013, Val Acc = 0.9028
# Epoch 891: Train Loss = 0.0500, Train Acc = 0.9733 | Val Loss = 0.8446, Val Acc = 0.9167
# Epoch 892: Train Loss = 0.0539, Train Acc = 0.9724 | Val Loss = 0.9175, Val Acc = 0.9167
# Epoch 893: Train Loss = 0.0653, Train Acc = 0.9681 | Val Loss = 1.2409, Val Acc = 0.9236
# Epoch 894: Train Loss = 0.0782, Train Acc = 0.9681 | Val Loss = 1.1419, Val Acc = 0.8889
# Epoch 895: Train Loss = 0.0817, Train Acc = 0.9689 | Val Loss = 1.1162, Val Acc = 0.9028
# Epoch 896: Train Loss = 0.0607, Train Acc = 0.9681 | Val Loss = 0.8578, Val Acc = 0.9097
# Epoch 897: Train Loss = 0.0530, Train Acc = 0.9724 | Val Loss = 0.8259, Val Acc = 0.9097
# Epoch 898: Train Loss = 0.0493, Train Acc = 0.9724 | Val Loss = 0.8245, Val Acc = 0.9097
# Epoch 899: Train Loss = 0.0478, Train Acc = 0.9750 | Val Loss = 0.8274, Val Acc = 0.9167
# Epoch 900: Train Loss = 0.0501, Train Acc = 0.9750 | Val Loss = 0.6858, Val Acc = 0.8958
# Epoch 901: Train Loss = 0.0478, Train Acc = 0.9724 | Val Loss = 0.9127, Val Acc = 0.9167
# Epoch 902: Train Loss = 0.0499, Train Acc = 0.9750 | Val Loss = 0.8425, Val Acc = 0.9306
# Epoch 903: Train Loss = 0.0482, Train Acc = 0.9758 | Val Loss = 0.8223, Val Acc = 0.9167
# Epoch 904: Train Loss = 0.0492, Train Acc = 0.9741 | Val Loss = 0.8661, Val Acc = 0.9028
# Epoch 905: Train Loss = 0.0489, Train Acc = 0.9750 | Val Loss = 0.8090, Val Acc = 0.9236
# Epoch 906: Train Loss = 0.0508, Train Acc = 0.9733 | Val Loss = 0.9217, Val Acc = 0.8958
# Epoch 907: Train Loss = 0.0534, Train Acc = 0.9698 | Val Loss = 0.8893, Val Acc = 0.9028
# Epoch 908: Train Loss = 0.0537, Train Acc = 0.9733 | Val Loss = 0.8462, Val Acc = 0.9097
# Epoch 909: Train Loss = 0.0497, Train Acc = 0.9733 | Val Loss = 0.7539, Val Acc = 0.9236
# Epoch 910: Train Loss = 0.0488, Train Acc = 0.9733 | Val Loss = 0.8217, Val Acc = 0.9097
# Epoch 911: Train Loss = 0.0625, Train Acc = 0.9724 | Val Loss = 0.8265, Val Acc = 0.9444
# Epoch 912: Train Loss = 0.0772, Train Acc = 0.9664 | Val Loss = 1.0002, Val Acc = 0.8958
# Epoch 913: Train Loss = 0.0642, Train Acc = 0.9672 | Val Loss = 0.7857, Val Acc = 0.9306
# Epoch 914: Train Loss = 0.0609, Train Acc = 0.9689 | Val Loss = 0.7242, Val Acc = 0.9236
# Epoch 915: Train Loss = 0.0547, Train Acc = 0.9741 | Val Loss = 0.7080, Val Acc = 0.9097
# Epoch 916: Train Loss = 0.0548, Train Acc = 0.9776 | Val Loss = 0.7624, Val Acc = 0.9097
# Epoch 917: Train Loss = 0.0497, Train Acc = 0.9758 | Val Loss = 0.8265, Val Acc = 0.9306
# Epoch 918: Train Loss = 0.0514, Train Acc = 0.9724 | Val Loss = 0.9115, Val Acc = 0.9167
# Epoch 919: Train Loss = 0.0737, Train Acc = 0.9698 | Val Loss = 0.7713, Val Acc = 0.9375
# Epoch 920: Train Loss = 0.0762, Train Acc = 0.9672 | Val Loss = 1.0554, Val Acc = 0.8750
# Epoch 921: Train Loss = 0.0848, Train Acc = 0.9664 | Val Loss = 0.7230, Val Acc = 0.9167
# Epoch 922: Train Loss = 0.0587, Train Acc = 0.9707 | Val Loss = 0.9013, Val Acc = 0.9028
# Epoch 923: Train Loss = 0.0505, Train Acc = 0.9724 | Val Loss = 0.7619, Val Acc = 0.9236
# Epoch 924: Train Loss = 0.0540, Train Acc = 0.9750 | Val Loss = 0.7919, Val Acc = 0.9236
# Epoch 925: Train Loss = 0.0526, Train Acc = 0.9689 | Val Loss = 0.7482, Val Acc = 0.9097
# Epoch 926: Train Loss = 0.0547, Train Acc = 0.9715 | Val Loss = 0.6409, Val Acc = 0.9167
# Epoch 927: Train Loss = 0.0588, Train Acc = 0.9655 | Val Loss = 0.7168, Val Acc = 0.9167
# Epoch 928: Train Loss = 0.0543, Train Acc = 0.9758 | Val Loss = 0.7703, Val Acc = 0.9236
# Epoch 929: Train Loss = 0.0494, Train Acc = 0.9758 | Val Loss = 0.8115, Val Acc = 0.9306
# Epoch 930: Train Loss = 0.0510, Train Acc = 0.9715 | Val Loss = 0.8295, Val Acc = 0.9306
# Epoch 931: Train Loss = 0.0454, Train Acc = 0.9758 | Val Loss = 0.7466, Val Acc = 0.9306
# Epoch 932: Train Loss = 0.0508, Train Acc = 0.9733 | Val Loss = 0.7733, Val Acc = 0.9236
# Epoch 933: Train Loss = 0.0563, Train Acc = 0.9698 | Val Loss = 1.0806, Val Acc = 0.9306
# Epoch 934: Train Loss = 0.0504, Train Acc = 0.9750 | Val Loss = 0.8477, Val Acc = 0.9167
# Epoch 935: Train Loss = 0.0473, Train Acc = 0.9767 | Val Loss = 0.8539, Val Acc = 0.9375
# Epoch 936: Train Loss = 0.0601, Train Acc = 0.9681 | Val Loss = 0.8781, Val Acc = 0.9236
# Epoch 937: Train Loss = 0.0564, Train Acc = 0.9672 | Val Loss = 1.0342, Val Acc = 0.9306
# Epoch 938: Train Loss = 0.1006, Train Acc = 0.9603 | Val Loss = 0.7401, Val Acc = 0.9375
# Epoch 939: Train Loss = 0.0675, Train Acc = 0.9664 | Val Loss = 0.7194, Val Acc = 0.9306
# Epoch 940: Train Loss = 0.0542, Train Acc = 0.9724 | Val Loss = 0.7540, Val Acc = 0.9028
# Epoch 941: Train Loss = 0.0559, Train Acc = 0.9672 | Val Loss = 0.7699, Val Acc = 0.9236
# Epoch 942: Train Loss = 0.0530, Train Acc = 0.9733 | Val Loss = 0.6636, Val Acc = 0.9097
# Epoch 943: Train Loss = 0.0487, Train Acc = 0.9724 | Val Loss = 0.6428, Val Acc = 0.9167
# Epoch 944: Train Loss = 0.0472, Train Acc = 0.9750 | Val Loss = 0.6683, Val Acc = 0.9236
# Epoch 945: Train Loss = 0.0576, Train Acc = 0.9698 | Val Loss = 0.6831, Val Acc = 0.9167
# Epoch 946: Train Loss = 0.0573, Train Acc = 0.9741 | Val Loss = 0.6548, Val Acc = 0.9306
# Epoch 947: Train Loss = 0.0502, Train Acc = 0.9767 | Val Loss = 0.8185, Val Acc = 0.9167
# Epoch 948: Train Loss = 0.0563, Train Acc = 0.9715 | Val Loss = 0.5307, Val Acc = 0.9236
# Epoch 949: Train Loss = 0.0538, Train Acc = 0.9724 | Val Loss = 0.7659, Val Acc = 0.9236
# Epoch 950: Train Loss = 0.0527, Train Acc = 0.9724 | Val Loss = 0.7224, Val Acc = 0.9306
# Epoch 951: Train Loss = 0.0632, Train Acc = 0.9638 | Val Loss = 0.7116, Val Acc = 0.9306
# Epoch 952: Train Loss = 0.0640, Train Acc = 0.9707 | Val Loss = 0.5680, Val Acc = 0.9306
# Epoch 953: Train Loss = 0.0711, Train Acc = 0.9733 | Val Loss = 0.6981, Val Acc = 0.9306
# Epoch 954: Train Loss = 0.0494, Train Acc = 0.9741 | Val Loss = 0.5631, Val Acc = 0.9097
# Epoch 955: Train Loss = 0.0566, Train Acc = 0.9733 | Val Loss = 0.7423, Val Acc = 0.9097
# Epoch 956: Train Loss = 0.0765, Train Acc = 0.9655 | Val Loss = 0.7341, Val Acc = 0.9236
# Epoch 957: Train Loss = 0.0565, Train Acc = 0.9724 | Val Loss = 0.7917, Val Acc = 0.9306
# Epoch 958: Train Loss = 0.0677, Train Acc = 0.9689 | Val Loss = 0.7860, Val Acc = 0.9097
# Epoch 959: Train Loss = 0.0525, Train Acc = 0.9715 | Val Loss = 0.9186, Val Acc = 0.9236
# Epoch 960: Train Loss = 0.0501, Train Acc = 0.9767 | Val Loss = 0.7468, Val Acc = 0.9236
# Epoch 961: Train Loss = 0.0513, Train Acc = 0.9689 | Val Loss = 0.7836, Val Acc = 0.9236
# Epoch 962: Train Loss = 0.0610, Train Acc = 0.9715 | Val Loss = 0.6021, Val Acc = 0.9028
# Epoch 963: Train Loss = 0.0710, Train Acc = 0.9620 | Val Loss = 0.8842, Val Acc = 0.9375
# Epoch 964: Train Loss = 0.0823, Train Acc = 0.9646 | Val Loss = 0.6679, Val Acc = 0.9167
# Epoch 965: Train Loss = 0.0601, Train Acc = 0.9698 | Val Loss = 0.9184, Val Acc = 0.9306
# Epoch 966: Train Loss = 0.0818, Train Acc = 0.9638 | Val Loss = 0.9250, Val Acc = 0.9167
# Epoch 967: Train Loss = 0.0759, Train Acc = 0.9707 | Val Loss = 0.7495, Val Acc = 0.9097
# Epoch 968: Train Loss = 0.0510, Train Acc = 0.9758 | Val Loss = 0.8444, Val Acc = 0.9236
# Epoch 969: Train Loss = 0.0500, Train Acc = 0.9733 | Val Loss = 0.7695, Val Acc = 0.9444
# Epoch 970: Train Loss = 0.0530, Train Acc = 0.9733 | Val Loss = 0.8392, Val Acc = 0.9167
# Epoch 971: Train Loss = 0.0554, Train Acc = 0.9715 | Val Loss = 0.9418, Val Acc = 0.9167
# Epoch 972: Train Loss = 0.0487, Train Acc = 0.9741 | Val Loss = 0.9979, Val Acc = 0.9167
# Epoch 973: Train Loss = 0.0489, Train Acc = 0.9733 | Val Loss = 0.9427, Val Acc = 0.9236
# Epoch 974: Train Loss = 0.0460, Train Acc = 0.9767 | Val Loss = 0.8879, Val Acc = 0.9306
# Epoch 975: Train Loss = 0.0476, Train Acc = 0.9724 | Val Loss = 0.8905, Val Acc = 0.9167
# Epoch 976: Train Loss = 0.0456, Train Acc = 0.9776 | Val Loss = 0.9421, Val Acc = 0.9097
# Epoch 977: Train Loss = 0.0488, Train Acc = 0.9698 | Val Loss = 0.8939, Val Acc = 0.9167
# Epoch 978: Train Loss = 0.0486, Train Acc = 0.9758 | Val Loss = 0.9309, Val Acc = 0.9167
# Epoch 979: Train Loss = 0.0541, Train Acc = 0.9707 | Val Loss = 0.9450, Val Acc = 0.9236
# Epoch 980: Train Loss = 0.0576, Train Acc = 0.9715 | Val Loss = 0.8078, Val Acc = 0.9167
# Epoch 981: Train Loss = 0.0526, Train Acc = 0.9707 | Val Loss = 0.8351, Val Acc = 0.9167
# Epoch 982: Train Loss = 0.0524, Train Acc = 0.9698 | Val Loss = 0.8726, Val Acc = 0.9167
# Epoch 983: Train Loss = 0.0538, Train Acc = 0.9733 | Val Loss = 0.8336, Val Acc = 0.9306
# Epoch 984: Train Loss = 0.0513, Train Acc = 0.9750 | Val Loss = 0.7569, Val Acc = 0.9236
# Epoch 985: Train Loss = 0.0533, Train Acc = 0.9715 | Val Loss = 0.8078, Val Acc = 0.9236
# Epoch 986: Train Loss = 0.0471, Train Acc = 0.9767 | Val Loss = 0.7780, Val Acc = 0.9375
# Epoch 987: Train Loss = 0.0590, Train Acc = 0.9767 | Val Loss = 0.7455, Val Acc = 0.9097
# Epoch 988: Train Loss = 0.0545, Train Acc = 0.9750 | Val Loss = 0.6998, Val Acc = 0.9097
# Epoch 989: Train Loss = 0.0498, Train Acc = 0.9724 | Val Loss = 0.8232, Val Acc = 0.9306
# Epoch 990: Train Loss = 0.0444, Train Acc = 0.9750 | Val Loss = 0.8092, Val Acc = 0.9167
# Epoch 991: Train Loss = 0.0473, Train Acc = 0.9750 | Val Loss = 0.8710, Val Acc = 0.9375
# Epoch 992: Train Loss = 0.0464, Train Acc = 0.9758 | Val Loss = 0.8872, Val Acc = 0.9167
# Epoch 993: Train Loss = 0.0589, Train Acc = 0.9741 | Val Loss = 0.5765, Val Acc = 0.9097
# Epoch 994: Train Loss = 0.0724, Train Acc = 0.9724 | Val Loss = 0.8827, Val Acc = 0.9306
# Epoch 995: Train Loss = 0.0781, Train Acc = 0.9715 | Val Loss = 0.8853, Val Acc = 0.8889
# Epoch 996: Train Loss = 0.0832, Train Acc = 0.9655 | Val Loss = 0.7605, Val Acc = 0.9028
# Epoch 997: Train Loss = 0.0986, Train Acc = 0.9569 | Val Loss = 0.8793, Val Acc = 0.9097
# Epoch 998: Train Loss = 0.0687, Train Acc = 0.9698 | Val Loss = 0.8214, Val Acc = 0.9167
# Epoch 999: Train Loss = 0.0593, Train Acc = 0.9724 | Val Loss = 1.0891, Val Acc = 0.8958
# Epoch 1000: Train Loss = 0.0530, Train Acc = 0.9741 | Val Loss = 0.7487, Val Acc = 0.9167

# %%
import torch
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch.utils.data import DataLoader

# Assume test_embeddings and test_labels are tensors or numpy arrays
test_dataset = EmbeddingDataset(tokenized_datasets_test_promoter["embeddings"], test_labels_promoter)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

model_clf.eval()
all_preds = []
all_labels = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x, batch_y = batch_x.to(device), batch_y.to(device)
        logits = model_clf(batch_x)
        preds = torch.argmax(logits, dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(batch_y.cpu().numpy())

# Compute metrics
accuracy = accuracy_score(all_labels, all_preds)
precision = precision_score(all_labels, all_preds, average="macro")
recall = recall_score(all_labels, all_preds, average="macro")
f1 = f1_score(all_labels, all_preds, average="macro")

print(f"Test Accuracy:  {accuracy:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall:    {recall:.4f}")
print(f"Test F1-score:  {f1:.4f}")
# Out:
# Test Accuracy:  0.9041
# Test Precision: 0.7564
# Test Recall:    0.7696
# Test F1-score:  0.7499
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
