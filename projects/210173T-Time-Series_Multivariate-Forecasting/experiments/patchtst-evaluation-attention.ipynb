# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/weather/weather.csv

# %%
# !git clone https://github.com/deshithagallage/PatchTST.git
# Out:
# Cloning into 'PatchTST'...
# remote: Enumerating objects: 380, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 380 (delta 100), reused 94 (delta 88), pack-reused 231 (from 2)
# Receiving objects: 100% (380/380), 16.19 MiB | 32.64 MiB/s, done.
# Resolving deltas: 100% (173/173), done.

# %%
cd PatchTST
# Out:
# /kaggle/working/PatchTST

# %%
# !git checkout dev-flash-attention
# Out:
# Branch 'dev-flash-attention' set up to track remote branch 'dev-flash-attention' from 'origin'.
# Switched to a new branch 'dev-flash-attention'

# %%
cd PatchTST_supervised
# Out:
# /kaggle/working/PatchTST/PatchTST_supervised

# %%
mkdir dataset

# %%
cd dataset
# Out:
# /kaggle/working/PatchTST/PatchTST_supervised/dataset

# %%
cp /kaggle/input/weather/weather.csv .

# %%
cd ..
# Out:
# /kaggle/working/PatchTST/PatchTST_supervised

# %%
print("=========== Train Using Baseline ===========")
# Out:
# =========== Train Using Baseline ===========

# %%
# !python run_enhanced_exp.py \
    --is_training 1 \
    --model_id Weather_Baseline \
    --model PatchTST \
    --data custom \
    --data_path weather.csv \
    --enc_in 21 \
    --c_out 21
# Out:
# Args in experiment:
# ...

# %%
print("=========== Train Using AutoCorrelation Only ===========")
# Out:
# =========== Train Using AutoCorrelation Only ===========

# %%
# !python run_enhanced_exp.py \
    --is_training 1 \
    --model_id Weather_AutoCorr \
    --model PatchTST \
    --data custom \
    --data_path weather.csv \
    --use_autocorr \
    --enc_in 21 \
    --c_out 21
# Out:
# Args in experiment:
# ...

# %%
print("=========== Train Using Fourier Cross-Attention Only ===========")
# Out:
# =========== Train Using Fourier Cross-Attention Only ===========

# %%
# !python run_enhanced_exp.py \
    --is_training 1 \
    --model_id Weather_Fourier \
    --model PatchTST \
    --data custom \
    --data_path weather.csv \
    --use_fourier \
    --enc_in 21 \
    --c_out 21
# Out:
# Args in experiment:
# ...

# %%
print("=========== Train Using Channel Attention Only ===========")
# Out:
# =========== Train Using Channel Attention Only ===========

# %%
# !python run_enhanced_exp.py \
    --is_training 1 \
    --model_id Weather_Channel \
    --model PatchTST \
    --data custom \
    --data_path weather.csv \
    --use_channel_attention \
    --enc_in 21 \
    --c_out 21
# Out:
# Args in experiment:
# ...

# %%
print("=========== Train Using Temporal Attention Only ===========")
# Out:
# =========== Train Using Temporal Attention Only ===========

# %%
# !python run_enhanced_exp.py \
    --is_training 1 \
    --model_id Weather_Temporal \
    --model PatchTST \
    --data custom \
    --data_path weather.csv \
    --use_temporal_attention \
    --enc_in 21 \
    --c_out 21
# Out:
# Args in experiment:
# ...

# %%
print("=========== Train Using AutoCorrelation + Fourier ===========")
# Out:
# =========== Train Using AutoCorrelation + Fourier ===========

# %%
# !python run_enhanced_exp.py \
    --is_training 1 \
    --model_id Weather_AC_FC \
    --model PatchTST \
    --data custom \
    --data_path weather.csv \
    --use_autocorr \
    --use_fourier \
    --enc_in 21 \
    --c_out 21
# Out:
# Args in experiment:
# ...

# %%
print("=========== Train Using All Attentions ===========")
# Out:
# =========== Train Using All Attentions ===========

# %%
# !python run_enhanced_exp.py \
    --is_training 1 \
    --model_id Weather_All \
    --model PatchTST \
    --data custom \
    --data_path weather.csv \
    --use_autocorr \
    --use_fourier \
    --use_channel_attention \
    --use_temporal_attention \
    --enc_in 21 \
    --c_out 21
# Out:
# Args in experiment:
# ...
